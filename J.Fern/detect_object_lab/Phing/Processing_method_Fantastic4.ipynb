# %% [markdown]
# # Fantastic 4
# ---

# %% [markdown]
# # 1. โหลดภาพหลักและแปลงเป็น RGB

# %% [markdown]
#     เป็นขั้นตอนแรกของการประมวลผลภาพ
#
# 1. โหลดไฟล์ภาพ
#  image = cv2.imread("../../../image/capture_test.jpg") ใช้ไลบรารี OpenCV (cv2) เพื่อโหลดไฟล์ภาพ ถ้าหาไฟล์ไม่เจอ cv2.imread() จะคืนค่าเป็น None
#
# 2. ตรวจสอบความถูกต้องของไฟล์
#  if image is None: raise FileNotFoundError("main_image.jpg not found") เป็นการตรวจสอบว่าการโหลดภาพสำเร็จหรือไม่ ถ้า image เป็น None ก็แสดงว่าหาไฟล์ไม่เจอ โค้ดก็จะหยุดทำงานและแจ้งข้อผิดพลาดให้ทราบ
#
# 3. แปลงสีของภาพ
#  โดยปกติแล้ว OpenCV จะโหลดภาพในรูปแบบสีแบบ BGR ซึ่งเป็นลำดับสีที่ต่างจากไลบรารีอื่นๆ เช่น Matplotlib ที่ใช้รูปแบบสีแบบ RGB การแปลงสีจาก BGR เป็น RGB ด้วย cv2.cvtColor(image, cv2.COLOR_BGR2RGB) จึงจำเป็นเพื่อให้การแสดงผลภาพด้วย Matplotlib ในภายหลัง

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 1. โหลดภาพหลักและแปลงเป็น RGB

image = cv2.imread("../../../image/night data/not use/1.jpg")
if image is None:
    raise FileNotFoundError("main_image.jpg not found")
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %% [markdown]
# # 2. ฟังก์ชันสร้าง Pink Mask

# %% [markdown]
# ฟังก์ชัน create_pink_mask()
#
#     มีไว้สำหรับสร้าง "มาสก์" (Mask) ที่ระบุตำแหน่งของสีชมพูในภาพ หลักการคือ
#
# 1. แปลงสีภาพ
#  ฟังก์ชันจะรับภาพในรูปแบบ RGB เข้ามา จากนั้นแปลงให้เป็นรูปแบบสี BGR แล้วแปลงเป็น HSV เพราะการระบุสีในรูปแบบนี้ง่ายและแม่นยำกว่าแบบ RGB มาก โดยค่า Hue จะใช้บอกชนิดของสี, Saturation บอกความอิ่มตัวของสี และ Value บอกความสว่างของสี
#
# 2. กำหนดช่วงสี
#  โค้ดจะกำหนดช่วงค่า HSV ที่เป็นสีชมพู โดยใช้ lower_pink และ upper_pink เพื่อระบุขอบเขตของสีที่ต้องการ
#
# 3. สร้างมาสก์
#  คำสั่ง cv2.inRange() จะสร้างภาพไบนารี (Binary Image) หรือ mask ขึ้นมา โดยพิกเซลที่เป็นสีชมพูตามช่วงที่กำหนดจะมีค่าเป็นสีขาว (255) ส่วนพิกเซลอื่นๆ จะมีค่าเป็นสีดำ (0)
#
# 4. ลด Noise
#  mask ที่ได้จาก cv2.inRange() อาจมี Noise cv2.medianBlur() จะช่วยลด Noise และ cv2.morphologyEx() จะช่วยเติมเต็มช่องว่างเล็ก ๆ ในมาสก์ ทำให้มาสก์มีความสมบูรณ์มากขึ้น

# %%
def create_pink_mask(img_rgb):
    
    # สร้าง mask สำหรับสีชมพู โดยใช้ HSV color space
    # แปลงเป็น HSV เพื่อจับสีชมพูได้ดีกว่า
    img_bgr = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2BGR)
    hsv = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2HSV)
    
    # ช่วงค่าต่ำสุดของสีชมพู
    lower_pink = np.array([120, 10, 100])
    # ช่วงค่าสูงสุดของสีชมพู
    upper_pink = np.array([170, 100, 200])
    
    # สร้าง mask
    mask = cv2.inRange(hsv, lower_pink, upper_pink)
    
    # เพิ่มการ morphology เพื่อลด noise
    mask = cv2.medianBlur(mask, 7)
    kernel = np.ones((7, 7), np.uint8)
    # ปิดช่องว่างเล็กๆ
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
    
    return mask

# %%
# สร้าง pink mask สำหรับภาพหลัก
main_pink_mask = create_pink_mask(image_rgb)

# แปลงภาพหลักเป็น grayscale และใช้ mask
main_gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)
main_masked = cv2.bitwise_and(main_gray, main_gray, mask=main_pink_mask)

# %% [markdown]
# # 3. โหลด template และเตรียม mask + grayscale

# %% [markdown]
# โหลด template และเตรียม mask + grayscale
#
#     ทำหน้าที่คล้ายกับ ฟังก์ชัน create_pink_mask() แต่ทำซ้ำสำหรับแต่ละ Template ที่ต้องการใช้ค้นหา
#
# 1. วนลูปโหลด Template
#  โค้ดจะวนลูปผ่านรายการไฟล์รูปภาพ Template ที่เตรียมไว้ 3 ขนาด
#
# 2. เตรียม Template แต่ละรูป
#  สำหรับ Template แต่ละรูป โค้ดจะ
# - โหลดภาพ Template
# - แปลงภาพจาก BGR เป็น RGB
# - ใช้ฟังก์ชัน create_pink_mask() ที่สร้างไว้ในส่วนที่ 2 เพื่อสร้างมาสก์สีชมพูสำหรับ Template
# - แปลงภาพ Template เป็นสีเทา (tmpl_gray)
# - นำมาสก์ที่ได้มาใช้กับภาพสีเทาด้วย cv2.bitwise_and() เพื่อให้ได้ภาพ Template ที่มีเฉพาะส่วนที่เป็นสีชมพูเท่านั้น (tmpl_masked)
#
# ผลลัพธ์ที่ได้คือรายการของภาพ Template ที่ผ่านการมาสก์แล้ว (templates_masked) ซึ่งพร้อมสำหรับการนำไปเปรียบเทียบกับภาพหลักที่ผ่านการมาสก์แล้ว (main_masked) ในขั้นตอน Template Matching ถัดไป

# %%
template1 = "../../../image/template/use/template_night_pic1_x_557_y_278_w_120_h_293.jpg"
template2 = "../../../image/template/use/template_night_pic2_x_609_y_290_w_57_h_138.jpg"
template3 = "../../../image/template/use/template_night_pic3_x_622_y_293_w_40_h_93.jpg"


template_files = [template1, template2, template3]
templates_masked = []
templates_rgb = []
templates_masks = []

for f in template_files:
    tmpl = cv2.imread(f)
    if tmpl is None:
        raise FileNotFoundError(f"{f} not found")
    
    tmpl_rgb = cv2.cvtColor(tmpl, cv2.COLOR_BGR2RGB)
    templates_rgb.append(tmpl_rgb)
    
    # สร้าง pink mask สำหรับ template
    tmpl_pink_mask = create_pink_mask(tmpl_rgb)
    templates_masks.append(tmpl_pink_mask)
    
    # แปลงเป็น grayscale และใช้ mask
    tmpl_gray = cv2.cvtColor(tmpl_rgb, cv2.COLOR_RGB2GRAY)
    tmpl_masked = cv2.bitwise_and(tmpl_gray, tmpl_gray, mask=tmpl_pink_mask)
    
    templates_masked.append(tmpl_masked)

# %% [markdown]
# # 4. ฟังก์ชันทำ Template Matching สำหรับ masked grayscale

# %% [markdown]
# ฟังก์ชัน match_template_masked()
# ขั้นตอนการทำงานหลักๆ
#
# 1. การทำ Template Matching
#  - result = cv2.matchTemplate(img_masked, tmpl_masked, cv2.TM_CCOEFF_NORMED) คำสั่งนี้คือคำสั่งหลักของฟังก์ชัน มันจะนำภาพหลักที่ผ่านการมาสก์แล้ว (img_masked) มาเปรียบเทียบกับภาพ Template ที่ผ่านการมาสก์แล้ว (tmpl_masked) โดยใช้เทคนิค cv2.TM_CCOEFF_NORMED
#  - cv2.TM_CCOEFF_NORMED เป็นหนึ่งในวิธีการคำนวณความคล้ายคลึงกันระหว่างภาพและ Template โดยให้ค่าความสัมพันธ์อยู่ในช่วง -1 ถึง 1
#     - ค่าเข้าใกล้ 1: หมายถึงภาพสองส่วนนั้นมีความคล้ายคลึงกันมากที่สุด (การจับคู่สมบูรณ์แบบ)
#     - ค่าเข้าใกล้ 0: หมายถึงไม่มีความสัมพันธ์กันเลย
#     - ค่าเข้าใกล้ -1: หมายถึงความสัมพันธ์ในเชิงตรงกันข้าม
#
# ผลลัพธ์ที่ได้ (result) คือภาพ 2 มิติ (คล้ายกับแผนที่ความร้อน) ที่แต่ละพิกเซลมีค่าความสัมพันธ์ (correlation score) บอกว่าตำแหน่งนั้นๆ ในภาพหลักมีความคล้ายคลึงกับ Template มากแค่ไหน
#
# 2. การหาตำแหน่งที่ตรงกัน
#  - locations = np.where(result >= threshold): โค้ดนี้จะค้นหาตำแหน่งทั้งหมดบนแผนที่ result ที่มีค่าความสัมพันธ์ สูงกว่าหรือเท่ากับค่า threshold ที่เรากำหนดไว้ (ในที่นี้คือ 0.8)
#  - ค่า threshold นี้เป็นตัวกำหนดว่าเรายอมรับการจับคู่ที่ "คล้าย" กันมากแค่ไหน ยิ่งค่าสูง การจับคู่ก็จะยิ่งเข้มงวดมากขึ้น
#  - np.where() จะคืนค่าเป็น tuple ของ arrays ที่เก็บพิกัดแถว (row) และคอลัมน์ (col) ของทุกตำแหน่งที่ตรงตามเงื่อนไข
#
# 3. การสร้างกรอบสี่เหลี่ยม (Bounding Boxes)
#  - for pt in zip(*locations[::-1]) ลูปนี้จะวนผ่านทุกพิกัดที่พบจากการค้นหาในขั้นตอนที่แล้ว locations[::-1] เป็นการสลับลำดับจาก (แถว, คอลัมน์) ให้เป็น (คอลัมน์, แถว) เพื่อให้ตรงกับรูปแบบ (x, y) ที่นิยมใช้ในการวาดกรอบ
#  - boxes.append((pt, (pt[0]+w, pt[1]+h))): สำหรับแต่ละพิกัด pt (ซึ่งคือมุมซ้ายบนของกรอบ) โค้ดจะคำนวณพิกัดของมุมขวาล่างโดยการเพิ่มความกว้าง (w) และความสูง (h) ของ Template เข้าไป จากนั้นจึงเก็บข้อมูลกรอบสี่เหลี่ยมทั้งหมดไว้ในรายการ boxes
#
# ฟังก์ชันนี้รับภาพที่ผ่านการมาสก์แล้วทั้งสองภาพ (ภาพหลักและ Template) จากนั้นนำมาเปรียบเทียบเพื่อสร้างแผนที่คะแนนความคล้ายคลึงกัน แล้วจึงค้นหาทุกตำแหน่งบนแผนที่ที่มีคะแนนสูงพอ (มากกว่า threshold) เพื่อสร้างเป็นกรอบสี่เหลี่ยม (Bounding Boxes) ที่ระบุตำแหน่งที่คาดว่าวัตถุเป้าหมายอยู่ในภาพหลัก

# %%
def match_template_masked(img_masked, tmpl_masked, threshold=0.8):
    """Template matching บน masked grayscale images"""
    result = cv2.matchTemplate(img_masked, tmpl_masked, cv2.TM_CCOEFF_NORMED)
    
    # หา location ที่ score >= threshold
    locations = np.where(result >= threshold)
    
    boxes = []
    h, w = tmpl_masked.shape
    
    for pt in zip(*locations[::-1]):  # แปลง (row, col) -> (x, y)
        boxes.append((pt, (pt[0]+w, pt[1]+h)))
    
    return boxes, result

# %% [markdown]
# # 5. ทำ matching สำหรับทุก template

# %% [markdown]
# การทำ Template Matching และวาดผลลัพธ์
#
# จะวนลูปเพื่อนำ Template แต่ละตัวมาจับคู่กับภาพหลัก แล้ววาดกรอบสี่เหลี่ยม (bounding box) ที่ตรวจจับได้ลงบนภาพต้นฉบับ
#  - ลูปสำหรับแต่ละ Template: โค้ดจะวนลูปผ่านรายการ templates_masked เพื่อจับคู่ Template แต่ละตัวกับ main_masked โดยใช้ฟังก์ชัน match_template_masked และใช้ค่า threshold = 0.5
#  - การวาดกรอบและข้อความ: เมื่อได้ตำแหน่งที่ตรวจจับได้ (ในตัวแปร boxes) โค้ดจะสร้างสำเนาของภาพต้นฉบับ (img_copy) และวนลูปวาดกรอบสี่เหลี่ยมสีเขียว ((0, 255, 0)) พร้อมกับข้อความระบุหมายเลข Template (T1, T2, T3) ลงไป นอกจากนี้ยังมีการเพิ่มพื้นหลังสีดำและวาดค่าความเชื่อมั่น (confidence score) สำหรับการตรวจจับแรกด้วย

# %%
threshold = 0.5
matched_results = []

for i, tmpl_masked in enumerate(templates_masked):
    boxes, result = match_template_masked(main_masked, tmpl_masked, threshold)
    
    # วาดกรอบบนภาพต้นฉบับ (RGB)
    img_copy = image_rgb.copy()
    for j, (top_left, bottom_right) in enumerate(boxes):
        # วาดกรอบสีเขียว
        cv2.rectangle(img_copy, top_left, bottom_right, (0, 255, 0), 2)
        
        # คำนวณตำแหน่งข้อความให้ไม่ล้นออกนอกภาพ
        text_x = max(5, top_left[0])  # ไม่ให้ติดขอบซ้าย
        text_y = max(25, top_left[1] - 5)  # ไม่ให้ติดขอบบน
        
        # ตรวจสอบว่าข้อความจะล้นออกขวาหรือไม่
        img_height, img_width = img_copy.shape[:2]
        if text_x > img_width - 50:  # ถ้าใกล้ขอบขวา
            text_x = bottom_right[0] - 50
        
        # วาดข้อความด้วยสีเหลือง (ไม่ใช่แดง) และเพิ่ม background
        # วาดพื้นหลังสีดำให้ข้อความ
        cv2.rectangle(img_copy, (text_x-2, text_y-18), (text_x+35, text_y+2), (0, 0, 0), -1)
        # วาดข้อความสีเหลือง
        cv2.putText(img_copy, f"T{i+1}", (text_x, text_y-5), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 0), 1)
        
        # เพิ่มข้อมูล confidence score (ถ้าต้องการ)
        if j == 0:  # แสดงเฉพาะตัวแรก
            conf_y = text_y + 15
            confidence = result[top_left[1], top_left[0]] if top_left[1] < result.shape[0] and top_left[0] < result.shape[1] else 0
            cv2.rectangle(img_copy, (text_x-2, conf_y-12), (text_x+60, conf_y+2), (0, 0, 0), -1)
            cv2.putText(img_copy, f"{confidence:.2f}", (text_x, conf_y-2), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0, 255, 255), 1)
    
    matched_results.append((img_copy, templates_rgb[i], len(boxes)))

# %% [markdown]
# # 6. แสดงผลด้วย subplot (เพิ่ม mask visualization)

# %% [markdown]
# การแสดงผลด้วยกราฟและรูปภาพ
#
#     ใช้ไลบรารี Matplotlib เพื่อแสดงผลลัพธ์ทั้งหมดในรูปแบบที่เข้าใจง่าย โดยจัดเรียงเป็นหลายแถว (Subplots)
#
# - แถวที่ 1-3
#  แสดงภาพ Template ที่ใช้ในการค้นหา, ภาพมาสก์สีชมพูของ Template, และภาพ Template ที่ผ่านการมาสก์และแปลงเป็น Grayscale แล้ว ซึ่งช่วยให้เราเห็นว่าภาพ Template ที่ใช้ในการค้นหาจริง ๆ มีลักษณะอย่างไร
#
# - แถวที่ 4
#  แสดงภาพมาสก์สีชมพูของภาพหลัก และภาพหลักที่ผ่านการมาสก์แล้ว
#
# - แถวที่ 5
#  แสดงผลลัพธ์สุดท้ายบนภาพหลัก โดยมีกรอบสีเขียวล้อมรอบจุดที่ตรวจจับได้ แต่ละรูปในแถวนี้จะแสดงผลลัพธ์สำหรับ Template แต่ละตัว พร้อมระบุจำนวนที่ตรวจจับได้ในหัวข้อ (Matches: n)

# %%
plt.figure(figsize=(20, 16))

# แถวที่ 1: Templates
for i, (img_res, tmpl_res, n_boxes) in enumerate(matched_results):
    plt.subplot(5, len(matched_results), i+1)
    plt.imshow(tmpl_res)
    plt.title(f"Template {i+1}")
    plt.axis("off")

# แถวที่ 2: Template masks
for i, tmpl_mask in enumerate(templates_masks):
    plt.subplot(5, len(matched_results), i+1+len(matched_results))
    plt.imshow(tmpl_mask, cmap='gray')
    plt.title(f"Template {i+1} Pink Mask")
    plt.axis("off")

# แถวที่ 3: Template masked (grayscale with mask applied)
for i, tmpl_masked in enumerate(templates_masked):
    plt.subplot(5, len(matched_results), i+1+2*len(matched_results))
    plt.imshow(tmpl_masked, cmap='gray')
    plt.title(f"Template {i+1} Masked")
    plt.axis("off")

# แถวที่ 4: Main image mask (แสดงเฉพาะรูปแรก)
plt.subplot(5, len(matched_results), 1+3*len(matched_results))
plt.imshow(main_pink_mask, cmap='gray')
plt.title("Main Image Pink Mask")
plt.axis("off")

plt.subplot(5, len(matched_results), 2+3*len(matched_results))
plt.imshow(main_masked, cmap='gray')
plt.title("Main Image Masked")
plt.axis("off")

# แถวที่ 5: ผล matching บนภาพ
for i, (img_res, tmpl_res, n_boxes) in enumerate(matched_results):
    plt.subplot(5, len(matched_results), i+1+4*len(matched_results))
    plt.imshow(img_res)
    plt.title(f"Matches: {n_boxes}")
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 7. แสดงผลสรุป

# %% [markdown]
# การแสดงผลลัพธ์แบบข้อความ
#
#     จะแสดงผลสรุปและรายละเอียดการตรวจจับในหน้าจอคอนโซล
#
#  - สรุปผล : จะพิมพ์ข้อความสรุปว่าแต่ละ Template พบการตรวจจับกี่ตำแหน่ง และเน้นย้ำว่าการใช้ Pink Mask ช่วยลด "false positive" (การตรวจจับที่ผิดพลาด) และเพิ่มความแม่นยำได้อย่างไร
#  - รายละเอียดการตรวจจับ : ฟังก์ชัน show_detection_details() จะถูกเรียกใช้เพื่อแสดงรายละเอียดเพิ่มเติมสำหรับแต่ละกรอบที่ตรวจจับได้ เช่น พิกัด (x, y) ความกว้าง (w) ความสูง (h) และค่าความเชื่อมั่น (confidence) ซึ่งเป็นข้อมูลเชิงลึกที่มีประโยชน์ในการวิเคราะห์ผลลัพธ์

# %%
print("=== Template Matching with Pink Mask Results ===")
for i, (_, _, n_boxes) in enumerate(matched_results):
    print(f"Template {i+1}: พบ {n_boxes} ตำแหน่ง")

print(f"\nThreshold ที่ใช้: {threshold}")
print("Pink mask ถูกใช้เพื่อมุ่งเน้นเฉพาะพื้นที่สีชมพูในการค้นหา")
print("ช่วยลด false positive และเพิ่มความแม่นยำในการ matching")
# Out:
# === Template Matching with Pink Mask Results ===
# Template 1: พบ 0 ตำแหน่ง
# Template 2: พบ 690 ตำแหน่ง
# Template 3: พบ 282 ตำแหน่ง
#
# Threshold ที่ใช้: 0.5
# Pink mask ถูกใช้เพื่อมุ่งเน้นเฉพาะพื้นที่สีชมพูในการค้นหา
# ช่วยลด false positive และเพิ่มความแม่นยำในการ matching

# %% [markdown]
# # 8. ฟังก์ชันเพิ่มเติม แสดงรายละเอียดการตรวจจับ

# %% [markdown]
# ฟังก์ชัน show_detection_details มีวัตถุประสงค์เพื่อแสดงข้อมูลเชิงลึกของการตรวจจับแต่ละครั้งที่โปรแกรมพบ
#
# - การวนลูป
# โค้ดจะวนลูปผ่าน Template แต่ละตัวอีกครั้ง เพื่อนำผลลัพธ์ boxes และ result มาใช้ในการแสดงข้อมูล
# - แสดงข้อมูล
#  ถ้ามีการตรวจจับได้ (len(boxes) > 0) โปรแกรมจะพิมพ์รายละเอียดของแต่ละกรอบที่พบออกมาในรูปแบบที่อ่านง่าย
# - ข้อมูลที่แสดง
#
#  รายละเอียดที่แสดงประกอบด้วย
#     - ตำแหน่ง (x, y): พิกัดของมุมซ้ายบนของกรอบสี่เหลี่ยม.
#     - ขนาด (w, h): ความกว้างและความสูงของกรอบ.
#     - ค่าความเชื่อมั่น (Confidence): ค่าความคล้ายคลึงที่ได้จากการทำ Template Matching ซึ่งยิ่งใกล้ 1 ยิ่งดี.

# %%
def show_detection_details():
    """แสดงรายละเอียดของการตรวจจับแต่ละ template"""
    print("\n=== Detection Details ===")
    
    for i, tmpl_masked in enumerate(templates_masked):
        boxes, result = match_template_masked(main_masked, tmpl_masked, threshold)
        
        if len(boxes) > 0:
            print(f"\nTemplate {i+1}:")
            for j, (top_left, bottom_right) in enumerate(boxes):
                x, y = top_left
                w = bottom_right[0] - top_left[0]
                h = bottom_right[1] - top_left[1]
                print(f"  Detection {j+1}: x={x}, y={y}, w={w}, h={h}")
                
                # คำนวณ confidence score ที่ตำแหน่งนั้น
                confidence = result[y, x] if y < result.shape[0] and x < result.shape[1] else 0
                print(f"    Confidence: {confidence:.3f}")
        else:
            print(f"\nTemplate {i+1}: ไม่พบการตรวจจับ")

show_detection_details()
# Out:
# === Detection Details ===
#
# Template 1: ไม่พบการตรวจจับ
#
# Template 2:
#   Detection 1: x=291, y=104, w=57, h=138
#     Confidence: 0.501
#   Detection 2: x=289, y=105, w=57, h=138
#     Confidence: 0.501
#   Detection 3: x=290, y=105, w=57, h=138
#     Confidence: 0.506
#   Detection 4: x=291, y=105, w=57, h=138
#     Confidence: 0.508
#   Detection 5: x=292, y=105, w=57, h=138
#     Confidence: 0.506
#   Detection 6: x=293, y=105, w=57, h=138
#     Confidence: 0.505
#   Detection 7: x=294, y=105, w=57, h=138
#     Confidence: 0.505
#   Detection 8: x=295, y=105, w=57, h=138
#     Confidence: 0.507
#   Detection 9: x=296, y=105, w=57, h=138
#     Confidence: 0.503
#   Detection 10: x=289, y=106, w=57, h=138
#     Confidence: 0.508
#   Detection 11: x=290, y=106, w=57, h=138
#     Confidence: 0.513
#   Detection 12: x=291, y=106, w=57, h=138
#     Confidence: 0.515
#   Detection 13: x=292, y=106, w=57, h=138
#     Confidence: 0.514
#   Detection 14: x=293, y=106, w=57, h=138
#     Confidence: 0.513
#   Detection 15: x=294, y=106, w=57, h=138
#     Confidence: 0.515
#   Detection 16: x=295, y=106, w=57, h=138
#     Confidence: 0.516
#   Detection 17: x=296, y=106, w=57, h=138
#     Confidence: 0.513
#   Detection 18: x=297, y=106, w=57, h=138
#     Confidence: 0.510
#   Detection 19: x=288, y=107, w=57, h=138
#     Confidence: 0.502
#   Detection 20: x=289, y=107, w=57, h=138
#     Confidence: 0.515
#   Detection 21: x=290, y=107, w=57, h=138
#     Confidence: 0.521
#   Detection 22: x=291, y=107, w=57, h=138
#     Confidence: 0.524
#   Detection 23: x=292, y=107, w=57, h=138
#     Confidence: 0.522
#   Detection 24: x=293, y=107, w=57, h=138
#     Confidence: 0.523
#   Detection 25: x=294, y=107, w=57, h=138
#     Confidence: 0.524
#   Detection 26: x=295, y=107, w=57, h=138
#     Confidence: 0.526
#   Detection 27: x=296, y=107, w=57, h=138
#     Confidence: 0.524
#   Detection 28: x=297, y=107, w=57, h=138
#     Confidence: 0.521
#   Detection 29: x=298, y=107, w=57, h=138
#     Confidence: 0.510
#   Detection 30: x=288, y=108, w=57, h=138
#     Confidence: 0.508
#   Detection 31: x=289, y=108, w=57, h=138
#     Confidence: 0.522
#   Detection 32: x=290, y=108, w=57, h=138
#     Confidence: 0.529
#   Detection 33: x=291, y=108, w=57, h=138
#     Confidence: 0.532
#   Detection 34: x=292, y=108, w=57, h=138
#     Confidence: 0.532
#   Detection 35: x=293, y=108, w=57, h=138
#     Confidence: 0.533
#   Detection 36: x=294, y=108, w=57, h=138
#     Confidence: 0.535
#   Detection 37: x=295, y=108, w=57, h=138
#     Confidence: 0.537
#   Detection 38: x=296, y=108, w=57, h=138
#     Confidence: 0.535
#   Detection 39: x=297, y=108, w=57, h=138
#     Confidence: 0.532
#   Detection 40: x=298, y=108, w=57, h=138
#     Confidence: 0.522
#   Detection 41: x=299, y=108, w=57, h=138
#     Confidence: 0.505
#   Detection 42: x=288, y=109, w=57, h=138
#     Confidence: 0.515
#   Detection 43: x=289, y=109, w=57, h=138
#     Confidence: 0.530
#   Detection 44: x=290, y=109, w=57, h=138
#     Confidence: 0.538
#   Detection 45: x=291, y=109, w=57, h=138
#     Confidence: 0.542
#   Detection 46: x=292, y=109, w=57, h=138
#     Confidence: 0.542
#   Detection 47: x=293, y=109, w=57, h=138
#     Confidence: 0.543
#   Detection 48: x=294, y=109, w=57, h=138
#     Confidence: 0.546
#   Detection 49: x=295, y=109, w=57, h=138
#     Confidence: 0.549
#   Detection 50: x=296, y=109, w=57, h=138
#     Confidence: 0.547
#   Detection 51: x=297, y=109, w=57, h=138
#     Confidence: 0.545
#   Detection 52: x=298, y=109, w=57, h=138
#     Confidence: 0.534
#   Detection 53: x=299, y=109, w=57, h=138
#     Confidence: 0.516
#   Detection 54: x=287, y=110, w=57, h=138
#     Confidence: 0.505
#   Detection 55: x=288, y=110, w=57, h=138
#     Confidence: 0.523
#   Detection 56: x=289, y=110, w=57, h=138
#     Confidence: 0.539
#   Detection 57: x=290, y=110, w=57, h=138
#     Confidence: 0.548
#   Detection 58: x=291, y=110, w=57, h=138
#     Confidence: 0.552
#   Detection 59: x=292, y=110, w=57, h=138
#     Confidence: 0.552
#   Detection 60: x=293, y=110, w=57, h=138
#     Confidence: 0.554
#   Detection 61: x=294, y=110, w=57, h=138
#     Confidence: 0.558
#   Detection 62: x=295, y=110, w=57, h=138
#     Confidence: 0.561
#   Detection 63: x=296, y=110, w=57, h=138
#     Confidence: 0.560
#   Detection 64: x=297, y=110, w=57, h=138
#     Confidence: 0.558
#   Detection 65: x=298, y=110, w=57, h=138
#     Confidence: 0.547
#   Detection 66: x=299, y=110, w=57, h=138
#     Confidence: 0.528
#   Detection 67: x=287, y=111, w=57, h=138
#     Confidence: 0.513
#   Detection 68: x=288, y=111, w=57, h=138
#     Confidence: 0.531
#   Detection 69: x=289, y=111, w=57, h=138
#     Confidence: 0.548
#   Detection 70: x=290, y=111, w=57, h=138
#     Confidence: 0.558
#   Detection 71: x=291, y=111, w=57, h=138
#     Confidence: 0.563
#   Detection 72: x=292, y=111, w=57, h=138
#     Confidence: 0.564
#   Detection 73: x=293, y=111, w=57, h=138
#     Confidence: 0.566
#   Detection 74: x=294, y=111, w=57, h=138
#     Confidence: 0.570
#   Detection 75: x=295, y=111, w=57, h=138
#     Confidence: 0.573
#   Detection 76: x=296, y=111, w=57, h=138
#     Confidence: 0.574
#   Detection 77: x=297, y=111, w=57, h=138
#     Confidence: 0.571
#   Detection 78: x=298, y=111, w=57, h=138
#     Confidence: 0.560
#   Detection 79: x=299, y=111, w=57, h=138
#     Confidence: 0.541
#   Detection 80: x=300, y=111, w=57, h=138
#     Confidence: 0.510
#   Detection 81: x=286, y=112, w=57, h=138
#     Confidence: 0.502
#   Detection 82: x=287, y=112, w=57, h=138
#     Confidence: 0.522
#   Detection 83: x=288, y=112, w=57, h=138
#     Confidence: 0.540
#   Detection 84: x=289, y=112, w=57, h=138
#     Confidence: 0.557
#   Detection 85: x=290, y=112, w=57, h=138
#     Confidence: 0.569
#   Detection 86: x=291, y=112, w=57, h=138
#     Confidence: 0.575
#   Detection 87: x=292, y=112, w=57, h=138
#     Confidence: 0.576
#   Detection 88: x=293, y=112, w=57, h=138
#     Confidence: 0.578
#   Detection 89: x=294, y=112, w=57, h=138
#     Confidence: 0.583
#   Detection 90: x=295, y=112, w=57, h=138
#     Confidence: 0.586
#   Detection 91: x=296, y=112, w=57, h=138
#     Confidence: 0.588
#   Detection 92: x=297, y=112, w=57, h=138
#     Confidence: 0.586
#   Detection 93: x=298, y=112, w=57, h=138
#     Confidence: 0.574
#   Detection 94: x=299, y=112, w=57, h=138
#     Confidence: 0.554
#   Detection 95: x=300, y=112, w=57, h=138
#     Confidence: 0.522
#   Detection 96: x=286, y=113, w=57, h=138
#     Confidence: 0.510
#   Detection 97: x=287, y=113, w=57, h=138
#     Confidence: 0.530
#   Detection 98: x=288, y=113, w=57, h=138
#     Confidence: 0.549
#   Detection 99: x=289, y=113, w=57, h=138
#     Confidence: 0.567
#   Detection 100: x=290, y=113, w=57, h=138
#     Confidence: 0.580
#   Detection 101: x=291, y=113, w=57, h=138
#     Confidence: 0.586
#   Detection 102: x=292, y=113, w=57, h=138
#     Confidence: 0.588
#   Detection 103: x=293, y=113, w=57, h=138
#     Confidence: 0.591
#   Detection 104: x=294, y=113, w=57, h=138
#     Confidence: 0.596
#   Detection 105: x=295, y=113, w=57, h=138
#     Confidence: 0.600
#   Detection 106: x=296, y=113, w=57, h=138
#     Confidence: 0.601
#   Detection 107: x=297, y=113, w=57, h=138
#     Confidence: 0.600
#   Detection 108: x=298, y=113, w=57, h=138
#     Confidence: 0.588
#   Detection 109: x=299, y=113, w=57, h=138
#     Confidence: 0.567
#   Detection 110: x=300, y=113, w=57, h=138
#     Confidence: 0.534
#   Detection 111: x=286, y=114, w=57, h=138
#     Confidence: 0.517
#   Detection 112: x=287, y=114, w=57, h=138
#     Confidence: 0.538
#   Detection 113: x=288, y=114, w=57, h=138
#     Confidence: 0.558
#   Detection 114: x=289, y=114, w=57, h=138
#     Confidence: 0.576
#   Detection 115: x=290, y=114, w=57, h=138
#     Confidence: 0.590
#   Detection 116: x=291, y=114, w=57, h=138
#     Confidence: 0.597
#   Detection 117: x=292, y=114, w=57, h=138
#     Confidence: 0.601
#   Detection 118: x=293, y=114, w=57, h=138
#     Confidence: 0.603
#   Detection 119: x=294, y=114, w=57, h=138
#     Confidence: 0.609
#   Detection 120: x=295, y=114, w=57, h=138
#     Confidence: 0.613
#   Detection 121: x=296, y=114, w=57, h=138
#     Confidence: 0.614
#   Detection 122: x=297, y=114, w=57, h=138
#     Confidence: 0.614
#   Detection 123: x=298, y=114, w=57, h=138
#     Confidence: 0.601
#   Detection 124: x=299, y=114, w=57, h=138
#     Confidence: 0.578
#   Detection 125: x=300, y=114, w=57, h=138
#     Confidence: 0.545
#   Detection 126: x=301, y=114, w=57, h=138
#     Confidence: 0.506
#   Detection 127: x=285, y=115, w=57, h=138
#     Confidence: 0.500
#   Detection 128: x=286, y=115, w=57, h=138
#     Confidence: 0.524
#   Detection 129: x=287, y=115, w=57, h=138
#     Confidence: 0.547
#   Detection 130: x=288, y=115, w=57, h=138
#     Confidence: 0.567
#   Detection 131: x=289, y=115, w=57, h=138
#     Confidence: 0.585
#   Detection 132: x=290, y=115, w=57, h=138
#     Confidence: 0.599
#   Detection 133: x=291, y=115, w=57, h=138
#     Confidence: 0.608
#   Detection 134: x=292, y=115, w=57, h=138
#     Confidence: 0.613
#   Detection 135: x=293, y=115, w=57, h=138
#     Confidence: 0.616
#   Detection 136: x=294, y=115, w=57, h=138
#     Confidence: 0.622
#   Detection 137: x=295, y=115, w=57, h=138
#     Confidence: 0.625
#   Detection 138: x=296, y=115, w=57, h=138
#     Confidence: 0.626
#   Detection 139: x=297, y=115, w=57, h=138
#     Confidence: 0.625
#   Detection 140: x=298, y=115, w=57, h=138
#     Confidence: 0.613
#   Detection 141: x=299, y=115, w=57, h=138
#     Confidence: 0.589
#   Detection 142: x=300, y=115, w=57, h=138
#     Confidence: 0.554
#   Detection 143: x=301, y=115, w=57, h=138
#     Confidence: 0.513
#   Detection 144: x=285, y=116, w=57, h=138
#     Confidence: 0.506
#   Detection 145: x=286, y=116, w=57, h=138
#     Confidence: 0.531
#   Detection 146: x=287, y=116, w=57, h=138
#     Confidence: 0.554
#   Detection 147: x=288, y=116, w=57, h=138
#     Confidence: 0.574
#   Detection 148: x=289, y=116, w=57, h=138
#     Confidence: 0.593
#   Detection 149: x=290, y=116, w=57, h=138
#     Confidence: 0.608
#   Detection 150: x=291, y=116, w=57, h=138
#     Confidence: 0.618
#   Detection 151: x=292, y=116, w=57, h=138
#     Confidence: 0.624
#   Detection 152: x=293, y=116, w=57, h=138
#     Confidence: 0.628
#   Detection 153: x=294, y=116, w=57, h=138
#     Confidence: 0.634
#   Detection 154: x=295, y=116, w=57, h=138
#     Confidence: 0.637
#   Detection 155: x=296, y=116, w=57, h=138
#     Confidence: 0.638
#   Detection 156: x=297, y=116, w=57, h=138
#     Confidence: 0.637
#   Detection 157: x=298, y=116, w=57, h=138
#     Confidence: 0.624
#   Detection 158: x=299, y=116, w=57, h=138
#     Confidence: 0.599
#   Detection 159: x=300, y=116, w=57, h=138
#     Confidence: 0.563
#   Detection 160: x=301, y=116, w=57, h=138
#     Confidence: 0.520
#   Detection 161: x=285, y=117, w=57, h=138
#     Confidence: 0.512
#   Detection 162: x=286, y=117, w=57, h=138
#     Confidence: 0.537
#   Detection 163: x=287, y=117, w=57, h=138
#     Confidence: 0.561
#   Detection 164: x=288, y=117, w=57, h=138
#     Confidence: 0.582
#   Detection 165: x=289, y=117, w=57, h=138
#     Confidence: 0.601
#   Detection 166: x=290, y=117, w=57, h=138
#     Confidence: 0.617
#   Detection 167: x=291, y=117, w=57, h=138
#     Confidence: 0.628
#   Detection 168: x=292, y=117, w=57, h=138
#     Confidence: 0.635
#   Detection 169: x=293, y=117, w=57, h=138
#     Confidence: 0.640
#   Detection 170: x=294, y=117, w=57, h=138
#     Confidence: 0.646
#   Detection 171: x=295, y=117, w=57, h=138
#     Confidence: 0.648
#   Detection 172: x=296, y=117, w=57, h=138
#     Confidence: 0.649
#   Detection 173: x=297, y=117, w=57, h=138
#     Confidence: 0.648
#   Detection 174: x=298, y=117, w=57, h=138
#     Confidence: 0.634
#   Detection 175: x=299, y=117, w=57, h=138
#     Confidence: 0.609
#   Detection 176: x=300, y=117, w=57, h=138
#     Confidence: 0.572
#   Detection 177: x=301, y=117, w=57, h=138
#     Confidence: 0.527
#   Detection 178: x=285, y=118, w=57, h=138
#     Confidence: 0.516
#   Detection 179: x=286, y=118, w=57, h=138
#     Confidence: 0.542
#   Detection 180: x=287, y=118, w=57, h=138
#     Confidence: 0.566
#   Detection 181: x=288, y=118, w=57, h=138
#     Confidence: 0.588
#   Detection 182: x=289, y=118, w=57, h=138
#     Confidence: 0.607
#   Detection 183: x=290, y=118, w=57, h=138
#     Confidence: 0.623
#   Detection 184: x=291, y=118, w=57, h=138
#     Confidence: 0.636
#   Detection 185: x=292, y=118, w=57, h=138
#     Confidence: 0.644
#   Detection 186: x=293, y=118, w=57, h=138
#     Confidence: 0.648
#   Detection 187: x=294, y=118, w=57, h=138
#     Confidence: 0.655
#   Detection 188: x=295, y=118, w=57, h=138
#     Confidence: 0.659
#   Detection 189: x=296, y=118, w=57, h=138
#     Confidence: 0.659
#   Detection 190: x=297, y=118, w=57, h=138
#     Confidence: 0.658
#   Detection 191: x=298, y=118, w=57, h=138
#     Confidence: 0.644
#   Detection 192: x=299, y=118, w=57, h=138
#     Confidence: 0.619
#   Detection 193: x=300, y=118, w=57, h=138
#     Confidence: 0.580
#   Detection 194: x=301, y=118, w=57, h=138
#     Confidence: 0.534
#   Detection 195: x=285, y=119, w=57, h=138
#     Confidence: 0.519
#   Detection 196: x=286, y=119, w=57, h=138
#     Confidence: 0.544
#   Detection 197: x=287, y=119, w=57, h=138
#     Confidence: 0.570
#   Detection 198: x=288, y=119, w=57, h=138
#     Confidence: 0.592
#   Detection 199: x=289, y=119, w=57, h=138
#     Confidence: 0.612
#   Detection 200: x=290, y=119, w=57, h=138
#     Confidence: 0.629
#   Detection 201: x=291, y=119, w=57, h=138
#     Confidence: 0.642
#   Detection 202: x=292, y=119, w=57, h=138
#     Confidence: 0.652
#   Detection 203: x=293, y=119, w=57, h=138
#     Confidence: 0.656
#   Detection 204: x=294, y=119, w=57, h=138
#     Confidence: 0.663
#   Detection 205: x=295, y=119, w=57, h=138
#     Confidence: 0.667
#   Detection 206: x=296, y=119, w=57, h=138
#     Confidence: 0.668
#   Detection 207: x=297, y=119, w=57, h=138
#     Confidence: 0.666
#   Detection 208: x=298, y=119, w=57, h=138
#     Confidence: 0.652
#   Detection 209: x=299, y=119, w=57, h=138
#     Confidence: 0.626
#   Detection 210: x=300, y=119, w=57, h=138
#     Confidence: 0.586
#   Detection 211: x=301, y=119, w=57, h=138
#     Confidence: 0.540
#   Detection 212: x=285, y=120, w=57, h=138
#     Confidence: 0.521
#   Detection 213: x=286, y=120, w=57, h=138
#     Confidence: 0.546
#   Detection 214: x=287, y=120, w=57, h=138
#     Confidence: 0.572
#   Detection 215: x=288, y=120, w=57, h=138
#     Confidence: 0.594
#   Detection 216: x=289, y=120, w=57, h=138
#     Confidence: 0.615
#   Detection 217: x=290, y=120, w=57, h=138
#     Confidence: 0.633
#   Detection 218: x=291, y=120, w=57, h=138
#     Confidence: 0.647
#   Detection 219: x=292, y=120, w=57, h=138
#     Confidence: 0.658
#   Detection 220: x=293, y=120, w=57, h=138
#     Confidence: 0.662
#   Detection 221: x=294, y=120, w=57, h=138
#     Confidence: 0.669
#   Detection 222: x=295, y=120, w=57, h=138
#     Confidence: 0.675
#   Detection 223: x=296, y=120, w=57, h=138
#     Confidence: 0.676
#   Detection 224: x=297, y=120, w=57, h=138
#     Confidence: 0.674
#   Detection 225: x=298, y=120, w=57, h=138
#     Confidence: 0.660
#   Detection 226: x=299, y=120, w=57, h=138
#     Confidence: 0.633
#   Detection 227: x=300, y=120, w=57, h=138
#     Confidence: 0.593
#   Detection 228: x=301, y=120, w=57, h=138
#     Confidence: 0.545
#   Detection 229: x=285, y=121, w=57, h=138
#     Confidence: 0.523
#   Detection 230: x=286, y=121, w=57, h=138
#     Confidence: 0.548
#   Detection 231: x=287, y=121, w=57, h=138
#     Confidence: 0.574
#   Detection 232: x=288, y=121, w=57, h=138
#     Confidence: 0.597
#   Detection 233: x=289, y=121, w=57, h=138
#     Confidence: 0.619
#   Detection 234: x=290, y=121, w=57, h=138
#     Confidence: 0.636
#   Detection 235: x=291, y=121, w=57, h=138
#     Confidence: 0.652
#   Detection 236: x=292, y=121, w=57, h=138
#     Confidence: 0.663
#   Detection 237: x=293, y=121, w=57, h=138
#     Confidence: 0.668
#   Detection 238: x=294, y=121, w=57, h=138
#     Confidence: 0.676
#   Detection 239: x=295, y=121, w=57, h=138
#     Confidence: 0.681
#   Detection 240: x=296, y=121, w=57, h=138
#     Confidence: 0.684
#   Detection 241: x=297, y=121, w=57, h=138
#     Confidence: 0.682
#   Detection 242: x=298, y=121, w=57, h=138
#     Confidence: 0.668
#   Detection 243: x=299, y=121, w=57, h=138
#     Confidence: 0.641
#   Detection 244: x=300, y=121, w=57, h=138
#     Confidence: 0.599
#   Detection 245: x=301, y=121, w=57, h=138
#     Confidence: 0.550
#   Detection 246: x=285, y=122, w=57, h=138
#     Confidence: 0.525
#   Detection 247: x=286, y=122, w=57, h=138
#     Confidence: 0.551
#   Detection 248: x=287, y=122, w=57, h=138
#     Confidence: 0.577
#   Detection 249: x=288, y=122, w=57, h=138
#     Confidence: 0.600
#   Detection 250: x=289, y=122, w=57, h=138
#     Confidence: 0.622
#   Detection 251: x=290, y=122, w=57, h=138
#     Confidence: 0.641
#   Detection 252: x=291, y=122, w=57, h=138
#     Confidence: 0.657
#   Detection 253: x=292, y=122, w=57, h=138
#     Confidence: 0.669
#   Detection 254: x=293, y=122, w=57, h=138
#     Confidence: 0.675
#   Detection 255: x=294, y=122, w=57, h=138
#     Confidence: 0.683
#   Detection 256: x=295, y=122, w=57, h=138
#     Confidence: 0.689
#   Detection 257: x=296, y=122, w=57, h=138
#     Confidence: 0.692
#   Detection 258: x=297, y=122, w=57, h=138
#     Confidence: 0.691
#   Detection 259: x=298, y=122, w=57, h=138
#     Confidence: 0.677
#   Detection 260: x=299, y=122, w=57, h=138
#     Confidence: 0.648
#   Detection 261: x=300, y=122, w=57, h=138
#     Confidence: 0.605
#   Detection 262: x=301, y=122, w=57, h=138
#     Confidence: 0.555
#   Detection 263: x=302, y=122, w=57, h=138
#     Confidence: 0.503
#   Detection 264: x=285, y=123, w=57, h=138
#     Confidence: 0.527
#   Detection 265: x=286, y=123, w=57, h=138
#     Confidence: 0.553
#   Detection 266: x=287, y=123, w=57, h=138
#     Confidence: 0.580
#   Detection 267: x=288, y=123, w=57, h=138
#     Confidence: 0.604
#   Detection 268: x=289, y=123, w=57, h=138
#     Confidence: 0.626
#   Detection 269: x=290, y=123, w=57, h=138
#     Confidence: 0.645
#   Detection 270: x=291, y=123, w=57, h=138
#     Confidence: 0.661
#   Detection 271: x=292, y=123, w=57, h=138
#     Confidence: 0.674
#   Detection 272: x=293, y=123, w=57, h=138
#     Confidence: 0.681
#   Detection 273: x=294, y=123, w=57, h=138
#     Confidence: 0.690
#   Detection 274: x=295, y=123, w=57, h=138
#     Confidence: 0.697
#   Detection 275: x=296, y=123, w=57, h=138
#     Confidence: 0.700
#   Detection 276: x=297, y=123, w=57, h=138
#     Confidence: 0.699
#   Detection 277: x=298, y=123, w=57, h=138
#     Confidence: 0.685
#   Detection 278: x=299, y=123, w=57, h=138
#     Confidence: 0.655
#   Detection 279: x=300, y=123, w=57, h=138
#     Confidence: 0.611
#   Detection 280: x=301, y=123, w=57, h=138
#     Confidence: 0.560
#   Detection 281: x=302, y=123, w=57, h=138
#     Confidence: 0.508
#   Detection 282: x=284, y=124, w=57, h=138
#     Confidence: 0.501
#   Detection 283: x=285, y=124, w=57, h=138
#     Confidence: 0.529
#   Detection 284: x=286, y=124, w=57, h=138
#     Confidence: 0.555
#   Detection 285: x=287, y=124, w=57, h=138
#     Confidence: 0.582
#   Detection 286: x=288, y=124, w=57, h=138
#     Confidence: 0.607
#   Detection 287: x=289, y=124, w=57, h=138
#     Confidence: 0.630
#   Detection 288: x=290, y=124, w=57, h=138
#     Confidence: 0.648
#   Detection 289: x=291, y=124, w=57, h=138
#     Confidence: 0.665
#   Detection 290: x=292, y=124, w=57, h=138
#     Confidence: 0.678
#   Detection 291: x=293, y=124, w=57, h=138
#     Confidence: 0.687
#   Detection 292: x=294, y=124, w=57, h=138
#     Confidence: 0.696
#   Detection 293: x=295, y=124, w=57, h=138
#     Confidence: 0.705
#   Detection 294: x=296, y=124, w=57, h=138
#     Confidence: 0.708
#   Detection 295: x=297, y=124, w=57, h=138
#     Confidence: 0.707
#   Detection 296: x=298, y=124, w=57, h=138
#     Confidence: 0.693
#   Detection 297: x=299, y=124, w=57, h=138
#     Confidence: 0.661
#   Detection 298: x=300, y=124, w=57, h=138
#     Confidence: 0.617
#   Detection 299: x=301, y=124, w=57, h=138
#     Confidence: 0.564
#   Detection 300: x=302, y=124, w=57, h=138
#     Confidence: 0.513
#   Detection 301: x=284, y=125, w=57, h=138
#     Confidence: 0.502
#   Detection 302: x=285, y=125, w=57, h=138
#     Confidence: 0.531
#   Detection 303: x=286, y=125, w=57, h=138
#     Confidence: 0.557
#   Detection 304: x=287, y=125, w=57, h=138
#     Confidence: 0.584
#   Detection 305: x=288, y=125, w=57, h=138
#     Confidence: 0.609
#   Detection 306: x=289, y=125, w=57, h=138
#     Confidence: 0.633
#   Detection 307: x=290, y=125, w=57, h=138
#     Confidence: 0.651
#   Detection 308: x=291, y=125, w=57, h=138
#     Confidence: 0.668
#   Detection 309: x=292, y=125, w=57, h=138
#     Confidence: 0.682
#   Detection 310: x=293, y=125, w=57, h=138
#     Confidence: 0.692
#   Detection 311: x=294, y=125, w=57, h=138
#     Confidence: 0.702
#   Detection 312: x=295, y=125, w=57, h=138
#     Confidence: 0.711
#   Detection 313: x=296, y=125, w=57, h=138
#     Confidence: 0.716
#   Detection 314: x=297, y=125, w=57, h=138
#     Confidence: 0.715
#   Detection 315: x=298, y=125, w=57, h=138
#     Confidence: 0.701
#   Detection 316: x=299, y=125, w=57, h=138
#     Confidence: 0.668
#   Detection 317: x=300, y=125, w=57, h=138
#     Confidence: 0.622
#   Detection 318: x=301, y=125, w=57, h=138
#     Confidence: 0.569
#   Detection 319: x=302, y=125, w=57, h=138
#     Confidence: 0.517
#   Detection 320: x=284, y=126, w=57, h=138
#     Confidence: 0.503
#   Detection 321: x=285, y=126, w=57, h=138
#     Confidence: 0.531
#   Detection 322: x=286, y=126, w=57, h=138
#     Confidence: 0.558
#   Detection 323: x=287, y=126, w=57, h=138
#     Confidence: 0.585
#   Detection 324: x=288, y=126, w=57, h=138
#     Confidence: 0.611
#   Detection 325: x=289, y=126, w=57, h=138
#     Confidence: 0.634
#   Detection 326: x=290, y=126, w=57, h=138
#     Confidence: 0.653
#   Detection 327: x=291, y=126, w=57, h=138
#     Confidence: 0.670
#   Detection 328: x=292, y=126, w=57, h=138
#     Confidence: 0.685
#   Detection 329: x=293, y=126, w=57, h=138
#     Confidence: 0.697
#   Detection 330: x=294, y=126, w=57, h=138
#     Confidence: 0.709
#   Detection 331: x=295, y=126, w=57, h=138
#     Confidence: 0.717
#   Detection 332: x=296, y=126, w=57, h=138
#     Confidence: 0.723
#   Detection 333: x=297, y=126, w=57, h=138
#     Confidence: 0.723
#   Detection 334: x=298, y=126, w=57, h=138
#     Confidence: 0.709
#   Detection 335: x=299, y=126, w=57, h=138
#     Confidence: 0.675
#   Detection 336: x=300, y=126, w=57, h=138
#     Confidence: 0.627
#   Detection 337: x=301, y=126, w=57, h=138
#     Confidence: 0.573
#   Detection 338: x=302, y=126, w=57, h=138
#     Confidence: 0.521
#   Detection 339: x=284, y=127, w=57, h=138
#     Confidence: 0.504
#   Detection 340: x=285, y=127, w=57, h=138
#     Confidence: 0.532
#   Detection 341: x=286, y=127, w=57, h=138
#     Confidence: 0.559
#   Detection 342: x=287, y=127, w=57, h=138
#     Confidence: 0.586
#   Detection 343: x=288, y=127, w=57, h=138
#     Confidence: 0.612
#   Detection 344: x=289, y=127, w=57, h=138
#     Confidence: 0.636
#   Detection 345: x=290, y=127, w=57, h=138
#     Confidence: 0.655
#   Detection 346: x=291, y=127, w=57, h=138
#     Confidence: 0.672
#   Detection 347: x=292, y=127, w=57, h=138
#     Confidence: 0.687
#   Detection 348: x=293, y=127, w=57, h=138
#     Confidence: 0.700
#   Detection 349: x=294, y=127, w=57, h=138
#     Confidence: 0.713
#   Detection 350: x=295, y=127, w=57, h=138
#     Confidence: 0.722
#   Detection 351: x=296, y=127, w=57, h=138
#     Confidence: 0.729
#   Detection 352: x=297, y=127, w=57, h=138
#     Confidence: 0.729
#   Detection 353: x=298, y=127, w=57, h=138
#     Confidence: 0.713
#   Detection 354: x=299, y=127, w=57, h=138
#     Confidence: 0.677
#   Detection 355: x=300, y=127, w=57, h=138
#     Confidence: 0.626
#   Detection 356: x=301, y=127, w=57, h=138
#     Confidence: 0.572
#   Detection 357: x=302, y=127, w=57, h=138
#     Confidence: 0.519
#   Detection 358: x=284, y=128, w=57, h=138
#     Confidence: 0.505
#   Detection 359: x=285, y=128, w=57, h=138
#     Confidence: 0.533
#   Detection 360: x=286, y=128, w=57, h=138
#     Confidence: 0.559
#   Detection 361: x=287, y=128, w=57, h=138
#     Confidence: 0.587
#   Detection 362: x=288, y=128, w=57, h=138
#     Confidence: 0.614
#   Detection 363: x=289, y=128, w=57, h=138
#     Confidence: 0.637
#   Detection 364: x=290, y=128, w=57, h=138
#     Confidence: 0.657
#   Detection 365: x=291, y=128, w=57, h=138
#     Confidence: 0.673
#   Detection 366: x=292, y=128, w=57, h=138
#     Confidence: 0.689
#   Detection 367: x=293, y=128, w=57, h=138
#     Confidence: 0.702
#   Detection 368: x=294, y=128, w=57, h=138
#     Confidence: 0.716
#   Detection 369: x=295, y=128, w=57, h=138
#     Confidence: 0.726
#   Detection 370: x=296, y=128, w=57, h=138
#     Confidence: 0.733
#   Detection 371: x=297, y=128, w=57, h=138
#     Confidence: 0.733
#   Detection 372: x=298, y=128, w=57, h=138
#     Confidence: 0.715
#   Detection 373: x=299, y=128, w=57, h=138
#     Confidence: 0.677
#   Detection 374: x=300, y=128, w=57, h=138
#     Confidence: 0.625
#   Detection 375: x=301, y=128, w=57, h=138
#     Confidence: 0.569
#   Detection 376: x=302, y=128, w=57, h=138
#     Confidence: 0.516
#   Detection 377: x=284, y=129, w=57, h=138
#     Confidence: 0.507
#   Detection 378: x=285, y=129, w=57, h=138
#     Confidence: 0.535
#   Detection 379: x=286, y=129, w=57, h=138
#     Confidence: 0.561
#   Detection 380: x=287, y=129, w=57, h=138
#     Confidence: 0.589
#   Detection 381: x=288, y=129, w=57, h=138
#     Confidence: 0.616
#   Detection 382: x=289, y=129, w=57, h=138
#     Confidence: 0.638
#   Detection 383: x=290, y=129, w=57, h=138
#     Confidence: 0.657
#   Detection 384: x=291, y=129, w=57, h=138
#     Confidence: 0.674
#   Detection 385: x=292, y=129, w=57, h=138
#     Confidence: 0.690
#   Detection 386: x=293, y=129, w=57, h=138
#     Confidence: 0.704
#   Detection 387: x=294, y=129, w=57, h=138
#     Confidence: 0.717
#   Detection 388: x=295, y=129, w=57, h=138
#     Confidence: 0.729
#   Detection 389: x=296, y=129, w=57, h=138
#     Confidence: 0.736
#   Detection 390: x=297, y=129, w=57, h=138
#     Confidence: 0.736
#   Detection 391: x=298, y=129, w=57, h=138
#     Confidence: 0.717
#   Detection 392: x=299, y=129, w=57, h=138
#     Confidence: 0.677
#   Detection 393: x=300, y=129, w=57, h=138
#     Confidence: 0.623
#   Detection 394: x=301, y=129, w=57, h=138
#     Confidence: 0.567
#   Detection 395: x=302, y=129, w=57, h=138
#     Confidence: 0.513
#   Detection 396: x=284, y=130, w=57, h=138
#     Confidence: 0.508
#   Detection 397: x=285, y=130, w=57, h=138
#     Confidence: 0.535
#   Detection 398: x=286, y=130, w=57, h=138
#     Confidence: 0.561
#   Detection 399: x=287, y=130, w=57, h=138
#     Confidence: 0.588
#   Detection 400: x=288, y=130, w=57, h=138
#     Confidence: 0.613
#   Detection 401: x=289, y=130, w=57, h=138
#     Confidence: 0.636
#   Detection 402: x=290, y=130, w=57, h=138
#     Confidence: 0.655
#   Detection 403: x=291, y=130, w=57, h=138
#     Confidence: 0.672
#   Detection 404: x=292, y=130, w=57, h=138
#     Confidence: 0.689
#   Detection 405: x=293, y=130, w=57, h=138
#     Confidence: 0.703
#   Detection 406: x=294, y=130, w=57, h=138
#     Confidence: 0.717
#   Detection 407: x=295, y=130, w=57, h=138
#     Confidence: 0.729
#   Detection 408: x=296, y=130, w=57, h=138
#     Confidence: 0.737
#   Detection 409: x=297, y=130, w=57, h=138
#     Confidence: 0.738
#   Detection 410: x=298, y=130, w=57, h=138
#     Confidence: 0.717
#   Detection 411: x=299, y=130, w=57, h=138
#     Confidence: 0.675
#   Detection 412: x=300, y=130, w=57, h=138
#     Confidence: 0.619
#   Detection 413: x=301, y=130, w=57, h=138
#     Confidence: 0.563
#   Detection 414: x=302, y=130, w=57, h=138
#     Confidence: 0.508
#   Detection 415: x=284, y=131, w=57, h=138
#     Confidence: 0.508
#   Detection 416: x=285, y=131, w=57, h=138
#     Confidence: 0.533
#   Detection 417: x=286, y=131, w=57, h=138
#     Confidence: 0.559
#   Detection 418: x=287, y=131, w=57, h=138
#     Confidence: 0.586
#   Detection 419: x=288, y=131, w=57, h=138
#     Confidence: 0.611
#   Detection 420: x=289, y=131, w=57, h=138
#     Confidence: 0.633
#   Detection 421: x=290, y=131, w=57, h=138
#     Confidence: 0.652
#   Detection 422: x=291, y=131, w=57, h=138
#     Confidence: 0.670
#   Detection 423: x=292, y=131, w=57, h=138
#     Confidence: 0.687
#   Detection 424: x=293, y=131, w=57, h=138
#     Confidence: 0.702
#   Detection 425: x=294, y=131, w=57, h=138
#     Confidence: 0.717
#   Detection 426: x=295, y=131, w=57, h=138
#     Confidence: 0.729
#   Detection 427: x=296, y=131, w=57, h=138
#     Confidence: 0.737
#   Detection 428: x=297, y=131, w=57, h=138
#     Confidence: 0.739
#   Detection 429: x=298, y=131, w=57, h=138
#     Confidence: 0.717
#   Detection 430: x=299, y=131, w=57, h=138
#     Confidence: 0.673
#   Detection 431: x=300, y=131, w=57, h=138
#     Confidence: 0.617
#   Detection 432: x=301, y=131, w=57, h=138
#     Confidence: 0.559
#   Detection 433: x=302, y=131, w=57, h=138
#     Confidence: 0.504
#   Detection 434: x=284, y=132, w=57, h=138
#     Confidence: 0.508
#   Detection 435: x=285, y=132, w=57, h=138
#     Confidence: 0.533
#   Detection 436: x=286, y=132, w=57, h=138
#     Confidence: 0.558
#   Detection 437: x=287, y=132, w=57, h=138
#     Confidence: 0.584
#   Detection 438: x=288, y=132, w=57, h=138
#     Confidence: 0.608
#   Detection 439: x=289, y=132, w=57, h=138
#     Confidence: 0.631
#   Detection 440: x=290, y=132, w=57, h=138
#     Confidence: 0.651
#   Detection 441: x=291, y=132, w=57, h=138
#     Confidence: 0.669
#   Detection 442: x=292, y=132, w=57, h=138
#     Confidence: 0.687
#   Detection 443: x=293, y=132, w=57, h=138
#     Confidence: 0.702
#   Detection 444: x=294, y=132, w=57, h=138
#     Confidence: 0.717
#   Detection 445: x=295, y=132, w=57, h=138
#     Confidence: 0.729
#   Detection 446: x=296, y=132, w=57, h=138
#     Confidence: 0.738
#   Detection 447: x=297, y=132, w=57, h=138
#     Confidence: 0.740
#   Detection 448: x=298, y=132, w=57, h=138
#     Confidence: 0.718
#   Detection 449: x=299, y=132, w=57, h=138
#     Confidence: 0.672
#   Detection 450: x=300, y=132, w=57, h=138
#     Confidence: 0.614
#   Detection 451: x=301, y=132, w=57, h=138
#     Confidence: 0.555
#   Detection 452: x=284, y=133, w=57, h=138
#     Confidence: 0.508
#   Detection 453: x=285, y=133, w=57, h=138
#     Confidence: 0.533
#   Detection 454: x=286, y=133, w=57, h=138
#     Confidence: 0.557
#   Detection 455: x=287, y=133, w=57, h=138
#     Confidence: 0.582
#   Detection 456: x=288, y=133, w=57, h=138
#     Confidence: 0.606
#   Detection 457: x=289, y=133, w=57, h=138
#     Confidence: 0.629
#   Detection 458: x=290, y=133, w=57, h=138
#     Confidence: 0.649
#   Detection 459: x=291, y=133, w=57, h=138
#     Confidence: 0.669
#   Detection 460: x=292, y=133, w=57, h=138
#     Confidence: 0.687
#   Detection 461: x=293, y=133, w=57, h=138
#     Confidence: 0.703
#   Detection 462: x=294, y=133, w=57, h=138
#     Confidence: 0.718
#   Detection 463: x=295, y=133, w=57, h=138
#     Confidence: 0.728
#   Detection 464: x=296, y=133, w=57, h=138
#     Confidence: 0.736
#   Detection 465: x=297, y=133, w=57, h=138
#     Confidence: 0.739
#   Detection 466: x=298, y=133, w=57, h=138
#     Confidence: 0.716
#   Detection 467: x=299, y=133, w=57, h=138
#     Confidence: 0.668
#   Detection 468: x=300, y=133, w=57, h=138
#     Confidence: 0.609
#   Detection 469: x=301, y=133, w=57, h=138
#     Confidence: 0.549
#   Detection 470: x=284, y=134, w=57, h=138
#     Confidence: 0.507
#   Detection 471: x=285, y=134, w=57, h=138
#     Confidence: 0.531
#   Detection 472: x=286, y=134, w=57, h=138
#     Confidence: 0.555
#   Detection 473: x=287, y=134, w=57, h=138
#     Confidence: 0.580
#   Detection 474: x=288, y=134, w=57, h=138
#     Confidence: 0.603
#   Detection 475: x=289, y=134, w=57, h=138
#     Confidence: 0.625
#   Detection 476: x=290, y=134, w=57, h=138
#     Confidence: 0.646
#   Detection 477: x=291, y=134, w=57, h=138
#     Confidence: 0.665
#   Detection 478: x=292, y=134, w=57, h=138
#     Confidence: 0.684
#   Detection 479: x=293, y=134, w=57, h=138
#     Confidence: 0.699
#   Detection 480: x=294, y=134, w=57, h=138
#     Confidence: 0.715
#   Detection 481: x=295, y=134, w=57, h=138
#     Confidence: 0.725
#   Detection 482: x=296, y=134, w=57, h=138
#     Confidence: 0.733
#   Detection 483: x=297, y=134, w=57, h=138
#     Confidence: 0.735
#   Detection 484: x=298, y=134, w=57, h=138
#     Confidence: 0.712
#   Detection 485: x=299, y=134, w=57, h=138
#     Confidence: 0.664
#   Detection 486: x=300, y=134, w=57, h=138
#     Confidence: 0.605
#   Detection 487: x=301, y=134, w=57, h=138
#     Confidence: 0.545
#   Detection 488: x=284, y=135, w=57, h=138
#     Confidence: 0.506
#   Detection 489: x=285, y=135, w=57, h=138
#     Confidence: 0.529
#   Detection 490: x=286, y=135, w=57, h=138
#     Confidence: 0.552
#   Detection 491: x=287, y=135, w=57, h=138
#     Confidence: 0.577
#   Detection 492: x=288, y=135, w=57, h=138
#     Confidence: 0.598
#   Detection 493: x=289, y=135, w=57, h=138
#     Confidence: 0.620
#   Detection 494: x=290, y=135, w=57, h=138
#     Confidence: 0.641
#   Detection 495: x=291, y=135, w=57, h=138
#     Confidence: 0.659
#   Detection 496: x=292, y=135, w=57, h=138
#     Confidence: 0.678
#   Detection 497: x=293, y=135, w=57, h=138
#     Confidence: 0.694
#   Detection 498: x=294, y=135, w=57, h=138
#     Confidence: 0.709
#   Detection 499: x=295, y=135, w=57, h=138
#     Confidence: 0.719
#   Detection 500: x=296, y=135, w=57, h=138
#     Confidence: 0.727
#   Detection 501: x=297, y=135, w=57, h=138
#     Confidence: 0.729
#   Detection 502: x=298, y=135, w=57, h=138
#     Confidence: 0.706
#   Detection 503: x=299, y=135, w=57, h=138
#     Confidence: 0.658
#   Detection 504: x=300, y=135, w=57, h=138
#     Confidence: 0.600
#   Detection 505: x=301, y=135, w=57, h=138
#     Confidence: 0.540
#   Detection 506: x=284, y=136, w=57, h=138
#     Confidence: 0.503
#   Detection 507: x=285, y=136, w=57, h=138
#     Confidence: 0.526
#   Detection 508: x=286, y=136, w=57, h=138
#     Confidence: 0.548
#   Detection 509: x=287, y=136, w=57, h=138
#     Confidence: 0.572
#   Detection 510: x=288, y=136, w=57, h=138
#     Confidence: 0.592
#   Detection 511: x=289, y=136, w=57, h=138
#     Confidence: 0.614
#   Detection 512: x=290, y=136, w=57, h=138
#     Confidence: 0.633
#   Detection 513: x=291, y=136, w=57, h=138
#     Confidence: 0.653
#   Detection 514: x=292, y=136, w=57, h=138
#     Confidence: 0.671
#   Detection 515: x=293, y=136, w=57, h=138
#     Confidence: 0.687
#   Detection 516: x=294, y=136, w=57, h=138
#     Confidence: 0.703
#   Detection 517: x=295, y=136, w=57, h=138
#     Confidence: 0.712
#   Detection 518: x=296, y=136, w=57, h=138
#     Confidence: 0.719
#   Detection 519: x=297, y=136, w=57, h=138
#     Confidence: 0.721
#   Detection 520: x=298, y=136, w=57, h=138
#     Confidence: 0.698
#   Detection 521: x=299, y=136, w=57, h=138
#     Confidence: 0.651
#   Detection 522: x=300, y=136, w=57, h=138
#     Confidence: 0.593
#   Detection 523: x=301, y=136, w=57, h=138
#     Confidence: 0.533
#   Detection 524: x=285, y=137, w=57, h=138
#     Confidence: 0.521
#   Detection 525: x=286, y=137, w=57, h=138
#     Confidence: 0.542
#   Detection 526: x=287, y=137, w=57, h=138
#     Confidence: 0.565
#   Detection 527: x=288, y=137, w=57, h=138
#     Confidence: 0.584
#   Detection 528: x=289, y=137, w=57, h=138
#     Confidence: 0.605
#   Detection 529: x=290, y=137, w=57, h=138
#     Confidence: 0.624
#   Detection 530: x=291, y=137, w=57, h=138
#     Confidence: 0.643
#   Detection 531: x=292, y=137, w=57, h=138
#     Confidence: 0.660
#   Detection 532: x=293, y=137, w=57, h=138
#     Confidence: 0.676
#   Detection 533: x=294, y=137, w=57, h=138
#     Confidence: 0.692
#   Detection 534: x=295, y=137, w=57, h=138
#     Confidence: 0.700
#   Detection 535: x=296, y=137, w=57, h=138
#     Confidence: 0.707
#   Detection 536: x=297, y=137, w=57, h=138
#     Confidence: 0.708
#   Detection 537: x=298, y=137, w=57, h=138
#     Confidence: 0.685
#   Detection 538: x=299, y=137, w=57, h=138
#     Confidence: 0.640
#   Detection 539: x=300, y=137, w=57, h=138
#     Confidence: 0.583
#   Detection 540: x=301, y=137, w=57, h=138
#     Confidence: 0.524
#   Detection 541: x=285, y=138, w=57, h=138
#     Confidence: 0.514
#   Detection 542: x=286, y=138, w=57, h=138
#     Confidence: 0.535
#   Detection 543: x=287, y=138, w=57, h=138
#     Confidence: 0.556
#   Detection 544: x=288, y=138, w=57, h=138
#     Confidence: 0.574
#   Detection 545: x=289, y=138, w=57, h=138
#     Confidence: 0.594
#   Detection 546: x=290, y=138, w=57, h=138
#     Confidence: 0.612
#   Detection 547: x=291, y=138, w=57, h=138
#     Confidence: 0.630
#   Detection 548: x=292, y=138, w=57, h=138
#     Confidence: 0.646
#   Detection 549: x=293, y=138, w=57, h=138
#     Confidence: 0.660
#   Detection 550: x=294, y=138, w=57, h=138
#     Confidence: 0.676
#   Detection 551: x=295, y=138, w=57, h=138
#     Confidence: 0.684
#   Detection 552: x=296, y=138, w=57, h=138
#     Confidence: 0.691
#   Detection 553: x=297, y=138, w=57, h=138
#     Confidence: 0.692
#   Detection 554: x=298, y=138, w=57, h=138
#     Confidence: 0.669
#   Detection 555: x=299, y=138, w=57, h=138
#     Confidence: 0.624
#   Detection 556: x=300, y=138, w=57, h=138
#     Confidence: 0.569
#   Detection 557: x=301, y=138, w=57, h=138
#     Confidence: 0.512
#   Detection 558: x=285, y=139, w=57, h=138
#     Confidence: 0.505
#   Detection 559: x=286, y=139, w=57, h=138
#     Confidence: 0.525
#   Detection 560: x=287, y=139, w=57, h=138
#     Confidence: 0.545
#   Detection 561: x=288, y=139, w=57, h=138
#     Confidence: 0.563
#   Detection 562: x=289, y=139, w=57, h=138
#     Confidence: 0.582
#   Detection 563: x=290, y=139, w=57, h=138
#     Confidence: 0.599
#   Detection 564: x=291, y=139, w=57, h=138
#     Confidence: 0.615
#   Detection 565: x=292, y=139, w=57, h=138
#     Confidence: 0.631
#   Detection 566: x=293, y=139, w=57, h=138
#     Confidence: 0.645
#   Detection 567: x=294, y=139, w=57, h=138
#     Confidence: 0.659
#   Detection 568: x=295, y=139, w=57, h=138
#     Confidence: 0.668
#   Detection 569: x=296, y=139, w=57, h=138
#     Confidence: 0.674
#   Detection 570: x=297, y=139, w=57, h=138
#     Confidence: 0.673
#   Detection 571: x=298, y=139, w=57, h=138
#     Confidence: 0.650
#   Detection 572: x=299, y=139, w=57, h=138
#     Confidence: 0.606
#   Detection 573: x=300, y=139, w=57, h=138
#     Confidence: 0.552
#   Detection 574: x=286, y=140, w=57, h=138
#     Confidence: 0.517
#   Detection 575: x=287, y=140, w=57, h=138
#     Confidence: 0.537
#   Detection 576: x=288, y=140, w=57, h=138
#     Confidence: 0.554
#   Detection 577: x=289, y=140, w=57, h=138
#     Confidence: 0.571
#   Detection 578: x=290, y=140, w=57, h=138
#     Confidence: 0.588
#   Detection 579: x=291, y=140, w=57, h=138
#     Confidence: 0.603
#   Detection 580: x=292, y=140, w=57, h=138
#     Confidence: 0.618
#   Detection 581: x=293, y=140, w=57, h=138
#     Confidence: 0.631
#   Detection 582: x=294, y=140, w=57, h=138
#     Confidence: 0.645
#   Detection 583: x=295, y=140, w=57, h=138
#     Confidence: 0.654
#   Detection 584: x=296, y=140, w=57, h=138
#     Confidence: 0.659
#   Detection 585: x=297, y=140, w=57, h=138
#     Confidence: 0.657
#   Detection 586: x=298, y=140, w=57, h=138
#     Confidence: 0.633
#   Detection 587: x=299, y=140, w=57, h=138
#     Confidence: 0.590
#   Detection 588: x=300, y=140, w=57, h=138
#     Confidence: 0.538
#   Detection 589: x=286, y=141, w=57, h=138
#     Confidence: 0.509
#   Detection 590: x=287, y=141, w=57, h=138
#     Confidence: 0.529
#   Detection 591: x=288, y=141, w=57, h=138
#     Confidence: 0.546
#   Detection 592: x=289, y=141, w=57, h=138
#     Confidence: 0.562
#   Detection 593: x=290, y=141, w=57, h=138
#     Confidence: 0.579
#   Detection 594: x=291, y=141, w=57, h=138
#     Confidence: 0.594
#   Detection 595: x=292, y=141, w=57, h=138
#     Confidence: 0.608
#   Detection 596: x=293, y=141, w=57, h=138
#     Confidence: 0.620
#   Detection 597: x=294, y=141, w=57, h=138
#     Confidence: 0.634
#   Detection 598: x=295, y=141, w=57, h=138
#     Confidence: 0.642
#   Detection 599: x=296, y=141, w=57, h=138
#     Confidence: 0.647
#   Detection 600: x=297, y=141, w=57, h=138
#     Confidence: 0.643
#   Detection 601: x=298, y=141, w=57, h=138
#     Confidence: 0.618
#   Detection 602: x=299, y=141, w=57, h=138
#     Confidence: 0.576
#   Detection 603: x=300, y=141, w=57, h=138
#     Confidence: 0.526
#   Detection 604: x=286, y=142, w=57, h=138
#     Confidence: 0.502
#   Detection 605: x=287, y=142, w=57, h=138
#     Confidence: 0.521
#   Detection 606: x=288, y=142, w=57, h=138
#     Confidence: 0.538
#   Detection 607: x=289, y=142, w=57, h=138
#     Confidence: 0.554
#   Detection 608: x=290, y=142, w=57, h=138
#     Confidence: 0.570
#   Detection 609: x=291, y=142, w=57, h=138
#     Confidence: 0.584
#   Detection 610: x=292, y=142, w=57, h=138
#     Confidence: 0.598
#   Detection 611: x=293, y=142, w=57, h=138
#     Confidence: 0.609
#   Detection 612: x=294, y=142, w=57, h=138
#     Confidence: 0.623
#   Detection 613: x=295, y=142, w=57, h=138
#     Confidence: 0.631
#   Detection 614: x=296, y=142, w=57, h=138
#     Confidence: 0.636
#   Detection 615: x=297, y=142, w=57, h=138
#     Confidence: 0.630
#   Detection 616: x=298, y=142, w=57, h=138
#     Confidence: 0.604
#   Detection 617: x=299, y=142, w=57, h=138
#     Confidence: 0.563
#   Detection 618: x=300, y=142, w=57, h=138
#     Confidence: 0.514
#   Detection 619: x=287, y=143, w=57, h=138
#     Confidence: 0.510
#   Detection 620: x=288, y=143, w=57, h=138
#     Confidence: 0.528
#   Detection 621: x=289, y=143, w=57, h=138
#     Confidence: 0.544
#   Detection 622: x=290, y=143, w=57, h=138
#     Confidence: 0.560
#   Detection 623: x=291, y=143, w=57, h=138
#     Confidence: 0.573
#   Detection 624: x=292, y=143, w=57, h=138
#     Confidence: 0.586
#   Detection 625: x=293, y=143, w=57, h=138
#     Confidence: 0.597
#   Detection 626: x=294, y=143, w=57, h=138
#     Confidence: 0.611
#   Detection 627: x=295, y=143, w=57, h=138
#     Confidence: 0.618
#   Detection 628: x=296, y=143, w=57, h=138
#     Confidence: 0.623
#   Detection 629: x=297, y=143, w=57, h=138
#     Confidence: 0.615
#   Detection 630: x=298, y=143, w=57, h=138
#     Confidence: 0.590
#   Detection 631: x=299, y=143, w=57, h=138
#     Confidence: 0.548
#   Detection 632: x=300, y=143, w=57, h=138
#     Confidence: 0.501
#   Detection 633: x=288, y=144, w=57, h=138
#     Confidence: 0.517
#   Detection 634: x=289, y=144, w=57, h=138
#     Confidence: 0.533
#   Detection 635: x=290, y=144, w=57, h=138
#     Confidence: 0.548
#   Detection 636: x=291, y=144, w=57, h=138
#     Confidence: 0.560
#   Detection 637: x=292, y=144, w=57, h=138
#     Confidence: 0.573
#   Detection 638: x=293, y=144, w=57, h=138
#     Confidence: 0.584
#   Detection 639: x=294, y=144, w=57, h=138
#     Confidence: 0.597
#   Detection 640: x=295, y=144, w=57, h=138
#     Confidence: 0.604
#   Detection 641: x=296, y=144, w=57, h=138
#     Confidence: 0.607
#   Detection 642: x=297, y=144, w=57, h=138
#     Confidence: 0.599
#   Detection 643: x=298, y=144, w=57, h=138
#     Confidence: 0.573
#   Detection 644: x=299, y=144, w=57, h=138
#     Confidence: 0.532
#   Detection 645: x=288, y=145, w=57, h=138
#     Confidence: 0.504
#   Detection 646: x=289, y=145, w=57, h=138
#     Confidence: 0.521
#   Detection 647: x=290, y=145, w=57, h=138
#     Confidence: 0.536
#   Detection 648: x=291, y=145, w=57, h=138
#     Confidence: 0.547
#   Detection 649: x=292, y=145, w=57, h=138
#     Confidence: 0.559
#   Detection 650: x=293, y=145, w=57, h=138
#     Confidence: 0.570
#   Detection 651: x=294, y=145, w=57, h=138
#     Confidence: 0.583
#   Detection 652: x=295, y=145, w=57, h=138
#     Confidence: 0.589
#   Detection 653: x=296, y=145, w=57, h=138
#     Confidence: 0.591
#   Detection 654: x=297, y=145, w=57, h=138
#     Confidence: 0.581
#   Detection 655: x=298, y=145, w=57, h=138
#     Confidence: 0.554
#   Detection 656: x=299, y=145, w=57, h=138
#     Confidence: 0.514
#   Detection 657: x=289, y=146, w=57, h=138
#     Confidence: 0.509
#   Detection 658: x=290, y=146, w=57, h=138
#     Confidence: 0.523
#   Detection 659: x=291, y=146, w=57, h=138
#     Confidence: 0.534
#   Detection 660: x=292, y=146, w=57, h=138
#     Confidence: 0.546
#   Detection 661: x=293, y=146, w=57, h=138
#     Confidence: 0.556
#   Detection 662: x=294, y=146, w=57, h=138
#     Confidence: 0.568
#   Detection 663: x=295, y=146, w=57, h=138
#     Confidence: 0.574
#   Detection 664: x=296, y=146, w=57, h=138
#     Confidence: 0.575
#   Detection 665: x=297, y=146, w=57, h=138
#     Confidence: 0.564
#   Detection 666: x=298, y=146, w=57, h=138
#     Confidence: 0.537
#   Detection 667: x=290, y=147, w=57, h=138
#     Confidence: 0.511
#   Detection 668: x=291, y=147, w=57, h=138
#     Confidence: 0.521
#   Detection 669: x=292, y=147, w=57, h=138
#     Confidence: 0.532
#   Detection 670: x=293, y=147, w=57, h=138
#     Confidence: 0.542
#   Detection 671: x=294, y=147, w=57, h=138
#     Confidence: 0.554
#   Detection 672: x=295, y=147, w=57, h=138
#     Confidence: 0.560
#   Detection 673: x=296, y=147, w=57, h=138
#     Confidence: 0.559
#   Detection 674: x=297, y=147, w=57, h=138
#     Confidence: 0.547
#   Detection 675: x=298, y=147, w=57, h=138
#     Confidence: 0.518
#   Detection 676: x=291, y=148, w=57, h=138
#     Confidence: 0.507
#   Detection 677: x=292, y=148, w=57, h=138
#     Confidence: 0.516
#   Detection 678: x=293, y=148, w=57, h=138
#     Confidence: 0.526
#   Detection 679: x=294, y=148, w=57, h=138
#     Confidence: 0.538
#   Detection 680: x=295, y=148, w=57, h=138
#     Confidence: 0.543
#   Detection 681: x=296, y=148, w=57, h=138
#     Confidence: 0.542
#   Detection 682: x=297, y=148, w=57, h=138
#     Confidence: 0.529
#   Detection 683: x=293, y=149, w=57, h=138
#     Confidence: 0.509
#   Detection 684: x=294, y=149, w=57, h=138
#     Confidence: 0.520
#   Detection 685: x=295, y=149, w=57, h=138
#     Confidence: 0.524
#   Detection 686: x=296, y=149, w=57, h=138
#     Confidence: 0.522
#   Detection 687: x=297, y=149, w=57, h=138
#     Confidence: 0.507
#   Detection 688: x=294, y=150, w=57, h=138
#     Confidence: 0.502
#   Detection 689: x=295, y=150, w=57, h=138
#     Confidence: 0.505
#   Detection 690: x=296, y=150, w=57, h=138
#     Confidence: 0.501
#
# Template 3:
#   Detection 1: x=293, y=122, w=40, h=93
#     Confidence: 0.504
#   Detection 2: x=294, y=122, w=40, h=93
#     Confidence: 0.510
#   Detection 3: x=295, y=122, w=40, h=93
#     Confidence: 0.509
#   Detection 4: x=296, y=122, w=40, h=93
#     Confidence: 0.506
#   Detection 5: x=293, y=123, w=40, h=93
#     Confidence: 0.514
#   Detection 6: x=294, y=123, w=40, h=93
#     Confidence: 0.522
#   Detection 7: x=295, y=123, w=40, h=93
#     Confidence: 0.522
#   Detection 8: x=296, y=123, w=40, h=93
#     Confidence: 0.519
#   Detection 9: x=297, y=123, w=40, h=93
#     Confidence: 0.508
#   Detection 10: x=292, y=124, w=40, h=93
#     Confidence: 0.503
#   Detection 11: x=293, y=124, w=40, h=93
#     Confidence: 0.523
#   Detection 12: x=294, y=124, w=40, h=93
#     Confidence: 0.531
#   Detection 13: x=295, y=124, w=40, h=93
#     Confidence: 0.535
#   Detection 14: x=296, y=124, w=40, h=93
#     Confidence: 0.530
#   Detection 15: x=297, y=124, w=40, h=93
#     Confidence: 0.520
#   Detection 16: x=298, y=124, w=40, h=93
#     Confidence: 0.510
#   Detection 17: x=292, y=125, w=40, h=93
#     Confidence: 0.510
#   Detection 18: x=293, y=125, w=40, h=93
#     Confidence: 0.529
#   Detection 19: x=294, y=125, w=40, h=93
#     Confidence: 0.539
#   Detection 20: x=295, y=125, w=40, h=93
#     Confidence: 0.542
#   Detection 21: x=296, y=125, w=40, h=93
#     Confidence: 0.538
#   Detection 22: x=297, y=125, w=40, h=93
#     Confidence: 0.527
#   Detection 23: x=298, y=125, w=40, h=93
#     Confidence: 0.516
#   Detection 24: x=299, y=125, w=40, h=93
#     Confidence: 0.502
#   Detection 25: x=292, y=126, w=40, h=93
#     Confidence: 0.515
#   Detection 26: x=293, y=126, w=40, h=93
#     Confidence: 0.531
#   Detection 27: x=294, y=126, w=40, h=93
#     Confidence: 0.541
#   Detection 28: x=295, y=126, w=40, h=93
#     Confidence: 0.544
#   Detection 29: x=296, y=126, w=40, h=93
#     Confidence: 0.539
#   Detection 30: x=297, y=126, w=40, h=93
#     Confidence: 0.529
#   Detection 31: x=298, y=126, w=40, h=93
#     Confidence: 0.517
#   Detection 32: x=299, y=126, w=40, h=93
#     Confidence: 0.500
#   Detection 33: x=291, y=127, w=40, h=93
#     Confidence: 0.501
#   Detection 34: x=292, y=127, w=40, h=93
#     Confidence: 0.520
#   Detection 35: x=293, y=127, w=40, h=93
#     Confidence: 0.534
#   Detection 36: x=294, y=127, w=40, h=93
#     Confidence: 0.543
#   Detection 37: x=295, y=127, w=40, h=93
#     Confidence: 0.545
#   Detection 38: x=296, y=127, w=40, h=93
#     Confidence: 0.540
#   Detection 39: x=297, y=127, w=40, h=93
#     Confidence: 0.529
#   Detection 40: x=298, y=127, w=40, h=93
#     Confidence: 0.519
#   Detection 41: x=291, y=128, w=40, h=93
#     Confidence: 0.507
#   Detection 42: x=292, y=128, w=40, h=93
#     Confidence: 0.524
#   Detection 43: x=293, y=128, w=40, h=93
#     Confidence: 0.538
#   Detection 44: x=294, y=128, w=40, h=93
#     Confidence: 0.545
#   Detection 45: x=295, y=128, w=40, h=93
#     Confidence: 0.547
#   Detection 46: x=296, y=128, w=40, h=93
#     Confidence: 0.542
#   Detection 47: x=297, y=128, w=40, h=93
#     Confidence: 0.529
#   Detection 48: x=298, y=128, w=40, h=93
#     Confidence: 0.518
#   Detection 49: x=291, y=129, w=40, h=93
#     Confidence: 0.514
#   Detection 50: x=292, y=129, w=40, h=93
#     Confidence: 0.530
#   Detection 51: x=293, y=129, w=40, h=93
#     Confidence: 0.544
#   Detection 52: x=294, y=129, w=40, h=93
#     Confidence: 0.550
#   Detection 53: x=295, y=129, w=40, h=93
#     Confidence: 0.550
#   Detection 54: x=296, y=129, w=40, h=93
#     Confidence: 0.545
#   Detection 55: x=297, y=129, w=40, h=93
#     Confidence: 0.532
#   Detection 56: x=298, y=129, w=40, h=93
#     Confidence: 0.516
#   Detection 57: x=290, y=130, w=40, h=93
#     Confidence: 0.503
#   Detection 58: x=291, y=130, w=40, h=93
#     Confidence: 0.524
#   Detection 59: x=292, y=130, w=40, h=93
#     Confidence: 0.538
#   Detection 60: x=293, y=130, w=40, h=93
#     Confidence: 0.550
#   Detection 61: x=294, y=130, w=40, h=93
#     Confidence: 0.555
#   Detection 62: x=295, y=130, w=40, h=93
#     Confidence: 0.554
#   Detection 63: x=296, y=130, w=40, h=93
#     Confidence: 0.545
#   Detection 64: x=297, y=130, w=40, h=93
#     Confidence: 0.532
#   Detection 65: x=298, y=130, w=40, h=93
#     Confidence: 0.513
#   Detection 66: x=290, y=131, w=40, h=93
#     Confidence: 0.515
#   Detection 67: x=291, y=131, w=40, h=93
#     Confidence: 0.536
#   Detection 68: x=292, y=131, w=40, h=93
#     Confidence: 0.547
#   Detection 69: x=293, y=131, w=40, h=93
#     Confidence: 0.555
#   Detection 70: x=294, y=131, w=40, h=93
#     Confidence: 0.558
#   Detection 71: x=295, y=131, w=40, h=93
#     Confidence: 0.555
#   Detection 72: x=296, y=131, w=40, h=93
#     Confidence: 0.547
#   Detection 73: x=297, y=131, w=40, h=93
#     Confidence: 0.531
#   Detection 74: x=298, y=131, w=40, h=93
#     Confidence: 0.512
#   Detection 75: x=289, y=132, w=40, h=93
#     Confidence: 0.504
#   Detection 76: x=290, y=132, w=40, h=93
#     Confidence: 0.528
#   Detection 77: x=291, y=132, w=40, h=93
#     Confidence: 0.548
#   Detection 78: x=292, y=132, w=40, h=93
#     Confidence: 0.557
#   Detection 79: x=293, y=132, w=40, h=93
#     Confidence: 0.562
#   Detection 80: x=294, y=132, w=40, h=93
#     Confidence: 0.564
#   Detection 81: x=295, y=132, w=40, h=93
#     Confidence: 0.557
#   Detection 82: x=296, y=132, w=40, h=93
#     Confidence: 0.548
#   Detection 83: x=297, y=132, w=40, h=93
#     Confidence: 0.532
#   Detection 84: x=298, y=132, w=40, h=93
#     Confidence: 0.512
#   Detection 85: x=289, y=133, w=40, h=93
#     Confidence: 0.518
#   Detection 86: x=290, y=133, w=40, h=93
#     Confidence: 0.540
#   Detection 87: x=291, y=133, w=40, h=93
#     Confidence: 0.559
#   Detection 88: x=292, y=133, w=40, h=93
#     Confidence: 0.567
#   Detection 89: x=293, y=133, w=40, h=93
#     Confidence: 0.573
#   Detection 90: x=294, y=133, w=40, h=93
#     Confidence: 0.571
#   Detection 91: x=295, y=133, w=40, h=93
#     Confidence: 0.563
#   Detection 92: x=296, y=133, w=40, h=93
#     Confidence: 0.551
#   Detection 93: x=297, y=133, w=40, h=93
#     Confidence: 0.533
#   Detection 94: x=298, y=133, w=40, h=93
#     Confidence: 0.512
#   Detection 95: x=288, y=134, w=40, h=93
#     Confidence: 0.503
#   Detection 96: x=289, y=134, w=40, h=93
#     Confidence: 0.531
#   Detection 97: x=290, y=134, w=40, h=93
#     Confidence: 0.552
#   Detection 98: x=291, y=134, w=40, h=93
#     Confidence: 0.570
#   Detection 99: x=292, y=134, w=40, h=93
#     Confidence: 0.579
#   Detection 100: x=293, y=134, w=40, h=93
#     Confidence: 0.583
#   Detection 101: x=294, y=134, w=40, h=93
#     Confidence: 0.581
#   Detection 102: x=295, y=134, w=40, h=93
#     Confidence: 0.569
#   Detection 103: x=296, y=134, w=40, h=93
#     Confidence: 0.555
#   Detection 104: x=297, y=134, w=40, h=93
#     Confidence: 0.537
#   Detection 105: x=298, y=134, w=40, h=93
#     Confidence: 0.514
#   Detection 106: x=288, y=135, w=40, h=93
#     Confidence: 0.515
#   Detection 107: x=289, y=135, w=40, h=93
#     Confidence: 0.542
#   Detection 108: x=290, y=135, w=40, h=93
#     Confidence: 0.564
#   Detection 109: x=291, y=135, w=40, h=93
#     Confidence: 0.582
#   Detection 110: x=292, y=135, w=40, h=93
#     Confidence: 0.591
#   Detection 111: x=293, y=135, w=40, h=93
#     Confidence: 0.596
#   Detection 112: x=294, y=135, w=40, h=93
#     Confidence: 0.591
#   Detection 113: x=295, y=135, w=40, h=93
#     Confidence: 0.578
#   Detection 114: x=296, y=135, w=40, h=93
#     Confidence: 0.561
#   Detection 115: x=297, y=135, w=40, h=93
#     Confidence: 0.542
#   Detection 116: x=298, y=135, w=40, h=93
#     Confidence: 0.518
#   Detection 117: x=288, y=136, w=40, h=93
#     Confidence: 0.525
#   Detection 118: x=289, y=136, w=40, h=93
#     Confidence: 0.552
#   Detection 119: x=290, y=136, w=40, h=93
#     Confidence: 0.575
#   Detection 120: x=291, y=136, w=40, h=93
#     Confidence: 0.594
#   Detection 121: x=292, y=136, w=40, h=93
#     Confidence: 0.603
#   Detection 122: x=293, y=136, w=40, h=93
#     Confidence: 0.608
#   Detection 123: x=294, y=136, w=40, h=93
#     Confidence: 0.603
#   Detection 124: x=295, y=136, w=40, h=93
#     Confidence: 0.587
#   Detection 125: x=296, y=136, w=40, h=93
#     Confidence: 0.569
#   Detection 126: x=297, y=136, w=40, h=93
#     Confidence: 0.548
#   Detection 127: x=298, y=136, w=40, h=93
#     Confidence: 0.524
#   Detection 128: x=287, y=137, w=40, h=93
#     Confidence: 0.506
#   Detection 129: x=288, y=137, w=40, h=93
#     Confidence: 0.536
#   Detection 130: x=289, y=137, w=40, h=93
#     Confidence: 0.562
#   Detection 131: x=290, y=137, w=40, h=93
#     Confidence: 0.585
#   Detection 132: x=291, y=137, w=40, h=93
#     Confidence: 0.605
#   Detection 133: x=292, y=137, w=40, h=93
#     Confidence: 0.615
#   Detection 134: x=293, y=137, w=40, h=93
#     Confidence: 0.620
#   Detection 135: x=294, y=137, w=40, h=93
#     Confidence: 0.615
#   Detection 136: x=295, y=137, w=40, h=93
#     Confidence: 0.598
#   Detection 137: x=296, y=137, w=40, h=93
#     Confidence: 0.579
#   Detection 138: x=297, y=137, w=40, h=93
#     Confidence: 0.556
#   Detection 139: x=298, y=137, w=40, h=93
#     Confidence: 0.531
#   Detection 140: x=299, y=137, w=40, h=93
#     Confidence: 0.505
#   Detection 141: x=287, y=138, w=40, h=93
#     Confidence: 0.517
#   Detection 142: x=288, y=138, w=40, h=93
#     Confidence: 0.545
#   Detection 143: x=289, y=138, w=40, h=93
#     Confidence: 0.571
#   Detection 144: x=290, y=138, w=40, h=93
#     Confidence: 0.595
#   Detection 145: x=291, y=138, w=40, h=93
#     Confidence: 0.615
#   Detection 146: x=292, y=138, w=40, h=93
#     Confidence: 0.626
#   Detection 147: x=293, y=138, w=40, h=93
#     Confidence: 0.632
#   Detection 148: x=294, y=138, w=40, h=93
#     Confidence: 0.625
#   Detection 149: x=295, y=138, w=40, h=93
#     Confidence: 0.608
#   Detection 150: x=296, y=138, w=40, h=93
#     Confidence: 0.589
#   Detection 151: x=297, y=138, w=40, h=93
#     Confidence: 0.564
#   Detection 152: x=298, y=138, w=40, h=93
#     Confidence: 0.538
#   Detection 153: x=299, y=138, w=40, h=93
#     Confidence: 0.512
#   Detection 154: x=287, y=139, w=40, h=93
#     Confidence: 0.525
#   Detection 155: x=288, y=139, w=40, h=93
#     Confidence: 0.553
#   Detection 156: x=289, y=139, w=40, h=93
#     Confidence: 0.577
#   Detection 157: x=290, y=139, w=40, h=93
#     Confidence: 0.600
#   Detection 158: x=291, y=139, w=40, h=93
#     Confidence: 0.621
#   Detection 159: x=292, y=139, w=40, h=93
#     Confidence: 0.635
#   Detection 160: x=293, y=139, w=40, h=93
#     Confidence: 0.642
#   Detection 161: x=294, y=139, w=40, h=93
#     Confidence: 0.635
#   Detection 162: x=295, y=139, w=40, h=93
#     Confidence: 0.619
#   Detection 163: x=296, y=139, w=40, h=93
#     Confidence: 0.598
#   Detection 164: x=297, y=139, w=40, h=93
#     Confidence: 0.574
#   Detection 165: x=298, y=139, w=40, h=93
#     Confidence: 0.547
#   Detection 166: x=299, y=139, w=40, h=93
#     Confidence: 0.519
#   Detection 167: x=287, y=140, w=40, h=93
#     Confidence: 0.532
#   Detection 168: x=288, y=140, w=40, h=93
#     Confidence: 0.558
#   Detection 169: x=289, y=140, w=40, h=93
#     Confidence: 0.581
#   Detection 170: x=290, y=140, w=40, h=93
#     Confidence: 0.604
#   Detection 171: x=291, y=140, w=40, h=93
#     Confidence: 0.626
#   Detection 172: x=292, y=140, w=40, h=93
#     Confidence: 0.644
#   Detection 173: x=293, y=140, w=40, h=93
#     Confidence: 0.653
#   Detection 174: x=294, y=140, w=40, h=93
#     Confidence: 0.645
#   Detection 175: x=295, y=140, w=40, h=93
#     Confidence: 0.631
#   Detection 176: x=296, y=140, w=40, h=93
#     Confidence: 0.609
#   Detection 177: x=297, y=140, w=40, h=93
#     Confidence: 0.585
#   Detection 178: x=298, y=140, w=40, h=93
#     Confidence: 0.558
#   Detection 179: x=299, y=140, w=40, h=93
#     Confidence: 0.529
#   Detection 180: x=287, y=141, w=40, h=93
#     Confidence: 0.527
#   Detection 181: x=288, y=141, w=40, h=93
#     Confidence: 0.551
#   Detection 182: x=289, y=141, w=40, h=93
#     Confidence: 0.575
#   Detection 183: x=290, y=141, w=40, h=93
#     Confidence: 0.598
#   Detection 184: x=291, y=141, w=40, h=93
#     Confidence: 0.620
#   Detection 185: x=292, y=141, w=40, h=93
#     Confidence: 0.640
#   Detection 186: x=293, y=141, w=40, h=93
#     Confidence: 0.650
#   Detection 187: x=294, y=141, w=40, h=93
#     Confidence: 0.644
#   Detection 188: x=295, y=141, w=40, h=93
#     Confidence: 0.631
#   Detection 189: x=296, y=141, w=40, h=93
#     Confidence: 0.609
#   Detection 190: x=297, y=141, w=40, h=93
#     Confidence: 0.585
#   Detection 191: x=298, y=141, w=40, h=93
#     Confidence: 0.557
#   Detection 192: x=299, y=141, w=40, h=93
#     Confidence: 0.527
#   Detection 193: x=287, y=142, w=40, h=93
#     Confidence: 0.515
#   Detection 194: x=288, y=142, w=40, h=93
#     Confidence: 0.539
#   Detection 195: x=289, y=142, w=40, h=93
#     Confidence: 0.563
#   Detection 196: x=290, y=142, w=40, h=93
#     Confidence: 0.587
#   Detection 197: x=291, y=142, w=40, h=93
#     Confidence: 0.609
#   Detection 198: x=292, y=142, w=40, h=93
#     Confidence: 0.631
#   Detection 199: x=293, y=142, w=40, h=93
#     Confidence: 0.642
#   Detection 200: x=294, y=142, w=40, h=93
#     Confidence: 0.638
#   Detection 201: x=295, y=142, w=40, h=93
#     Confidence: 0.625
#   Detection 202: x=296, y=142, w=40, h=93
#     Confidence: 0.603
#   Detection 203: x=297, y=142, w=40, h=93
#     Confidence: 0.581
#   Detection 204: x=298, y=142, w=40, h=93
#     Confidence: 0.552
#   Detection 205: x=299, y=142, w=40, h=93
#     Confidence: 0.521
#   Detection 206: x=287, y=143, w=40, h=93
#     Confidence: 0.501
#   Detection 207: x=288, y=143, w=40, h=93
#     Confidence: 0.526
#   Detection 208: x=289, y=143, w=40, h=93
#     Confidence: 0.550
#   Detection 209: x=290, y=143, w=40, h=93
#     Confidence: 0.574
#   Detection 210: x=291, y=143, w=40, h=93
#     Confidence: 0.597
#   Detection 211: x=292, y=143, w=40, h=93
#     Confidence: 0.618
#   Detection 212: x=293, y=143, w=40, h=93
#     Confidence: 0.631
#   Detection 213: x=294, y=143, w=40, h=93
#     Confidence: 0.630
#   Detection 214: x=295, y=143, w=40, h=93
#     Confidence: 0.617
#   Detection 215: x=296, y=143, w=40, h=93
#     Confidence: 0.597
#   Detection 216: x=297, y=143, w=40, h=93
#     Confidence: 0.574
#   Detection 217: x=298, y=143, w=40, h=93
#     Confidence: 0.545
#   Detection 218: x=299, y=143, w=40, h=93
#     Confidence: 0.513
#   Detection 219: x=288, y=144, w=40, h=93
#     Confidence: 0.513
#   Detection 220: x=289, y=144, w=40, h=93
#     Confidence: 0.537
#   Detection 221: x=290, y=144, w=40, h=93
#     Confidence: 0.561
#   Detection 222: x=291, y=144, w=40, h=93
#     Confidence: 0.583
#   Detection 223: x=292, y=144, w=40, h=93
#     Confidence: 0.604
#   Detection 224: x=293, y=144, w=40, h=93
#     Confidence: 0.617
#   Detection 225: x=294, y=144, w=40, h=93
#     Confidence: 0.621
#   Detection 226: x=295, y=144, w=40, h=93
#     Confidence: 0.609
#   Detection 227: x=296, y=144, w=40, h=93
#     Confidence: 0.589
#   Detection 228: x=297, y=144, w=40, h=93
#     Confidence: 0.567
#   Detection 229: x=298, y=144, w=40, h=93
#     Confidence: 0.537
#   Detection 230: x=299, y=144, w=40, h=93
#     Confidence: 0.502
#   Detection 231: x=289, y=145, w=40, h=93
#     Confidence: 0.522
#   Detection 232: x=290, y=145, w=40, h=93
#     Confidence: 0.546
#   Detection 233: x=291, y=145, w=40, h=93
#     Confidence: 0.569
#   Detection 234: x=292, y=145, w=40, h=93
#     Confidence: 0.590
#   Detection 235: x=293, y=145, w=40, h=93
#     Confidence: 0.601
#   Detection 236: x=294, y=145, w=40, h=93
#     Confidence: 0.607
#   Detection 237: x=295, y=145, w=40, h=93
#     Confidence: 0.599
#   Detection 238: x=296, y=145, w=40, h=93
#     Confidence: 0.580
#   Detection 239: x=297, y=145, w=40, h=93
#     Confidence: 0.558
#   Detection 240: x=298, y=145, w=40, h=93
#     Confidence: 0.527
#   Detection 241: x=289, y=146, w=40, h=93
#     Confidence: 0.508
#   Detection 242: x=290, y=146, w=40, h=93
#     Confidence: 0.532
#   Detection 243: x=291, y=146, w=40, h=93
#     Confidence: 0.555
#   Detection 244: x=292, y=146, w=40, h=93
#     Confidence: 0.575
#   Detection 245: x=293, y=146, w=40, h=93
#     Confidence: 0.586
#   Detection 246: x=294, y=146, w=40, h=93
#     Confidence: 0.591
#   Detection 247: x=295, y=146, w=40, h=93
#     Confidence: 0.586
#   Detection 248: x=296, y=146, w=40, h=93
#     Confidence: 0.570
#   Detection 249: x=297, y=146, w=40, h=93
#     Confidence: 0.548
#   Detection 250: x=298, y=146, w=40, h=93
#     Confidence: 0.514
#   Detection 251: x=290, y=147, w=40, h=93
#     Confidence: 0.518
#   Detection 252: x=291, y=147, w=40, h=93
#     Confidence: 0.541
#   Detection 253: x=292, y=147, w=40, h=93
#     Confidence: 0.559
#   Detection 254: x=293, y=147, w=40, h=93
#     Confidence: 0.571
#   Detection 255: x=294, y=147, w=40, h=93
#     Confidence: 0.575
#   Detection 256: x=295, y=147, w=40, h=93
#     Confidence: 0.571
#   Detection 257: x=296, y=147, w=40, h=93
#     Confidence: 0.559
#   Detection 258: x=297, y=147, w=40, h=93
#     Confidence: 0.537
#   Detection 259: x=298, y=147, w=40, h=93
#     Confidence: 0.501
#   Detection 260: x=290, y=148, w=40, h=93
#     Confidence: 0.504
#   Detection 261: x=291, y=148, w=40, h=93
#     Confidence: 0.527
#   Detection 262: x=292, y=148, w=40, h=93
#     Confidence: 0.544
#   Detection 263: x=293, y=148, w=40, h=93
#     Confidence: 0.555
#   Detection 264: x=294, y=148, w=40, h=93
#     Confidence: 0.560
#   Detection 265: x=295, y=148, w=40, h=93
#     Confidence: 0.553
#   Detection 266: x=296, y=148, w=40, h=93
#     Confidence: 0.544
#   Detection 267: x=297, y=148, w=40, h=93
#     Confidence: 0.522
#   Detection 268: x=291, y=149, w=40, h=93
#     Confidence: 0.512
#   Detection 269: x=292, y=149, w=40, h=93
#     Confidence: 0.529
#   Detection 270: x=293, y=149, w=40, h=93
#     Confidence: 0.540
#   Detection 271: x=294, y=149, w=40, h=93
#     Confidence: 0.543
#   Detection 272: x=295, y=149, w=40, h=93
#     Confidence: 0.536
#   Detection 273: x=296, y=149, w=40, h=93
#     Confidence: 0.526
#   Detection 274: x=297, y=149, w=40, h=93
#     Confidence: 0.504
#   Detection 275: x=292, y=150, w=40, h=93
#     Confidence: 0.514
#   Detection 276: x=293, y=150, w=40, h=93
#     Confidence: 0.526
#   Detection 277: x=294, y=150, w=40, h=93
#     Confidence: 0.526
#   Detection 278: x=295, y=150, w=40, h=93
#     Confidence: 0.519
#   Detection 279: x=296, y=150, w=40, h=93
#     Confidence: 0.506
#   Detection 280: x=293, y=151, w=40, h=93
#     Confidence: 0.511
#   Detection 281: x=294, y=151, w=40, h=93
#     Confidence: 0.508
#   Detection 282: x=295, y=151, w=40, h=93
#     Confidence: 0.501

# %% [markdown]
# # 9. Non-Maximum Suppression (NMS) เพื่อลดการทับซ้อน

# %% [markdown]
#     ใช้แก้ปัญหาการตรวจจับซ้ำซ้อน เทคนิค Non-Maximum Suppression (NMS)คือกระบวนการที่คัดเลือก bounding box ที่ดีที่สุดจากกลุ่ม bounding box ที่ทับซ้อนกันเพื่อกำจัดกรอบที่ไม่จำเป็นออกไป
#
# ฟังก์ชัน calculate_iou (การคำนวณ IoU)
# - oU ย่อมาจาก Intersection over Union เป็นตัวชี้วัดที่ใช้ประเมินว่ากรอบสี่เหลี่ยมสองอันทับซ้อนกันมากแค่ไหน
#
# หลักการ
#
# หาพื้นที่ทับซ้อน (Intersection) คำนวณพื้นที่ของส่วนที่กรอบทั้งสองทับซ้อนกัน หาพื้นที่รวม (Union) คำนวณพื้นที่รวมทั้งหมดของกรอบทั้งสอง (พื้นที่ของกรอบ A + พื้นที่ของกรอบ B - พื้นที่ทับซ้อน)
#
# คำนวณ IoU นำพื้นที่ทับซ้อนหารด้วยพื้นที่รวม ผลลัพธ์ที่ได้จะเป็นค่าระหว่าง 0 ถึง 1
#
# - ค่า IoU
#
# IoU = 0 ไม่มีพื้นที่ทับซ้อนกันเลย
# IoU = 1 กรอบทั้งสองซ้อนทับกันอย่างสมบูรณ์
#
# ฟังก์ชันนี้จะถูกใช้ใน non_maximum_suppression เพื่อเป็นเกณฑ์ในการตัดสินใจว่าจะกำจัดกรอบไหนทิ้ง

# %% [markdown]
# ฟังก์ชัน non_maximum_suppression (NMS)
#
# ขั้นตอนการทำงาน
#
#  - เรียงลำดับ เรียงกรอบสี่เหลี่ยมทั้งหมดตามค่าความเชื่อมั่น (confidence score) จากมากไปน้อย.
#  - เลือกกรอบที่ดีที่สุด เลือกกรอบแรกที่มีค่าความเชื่อมั่นสูงสุดออกมา.
#  - เปรียบเทียบและกำจัด เปรียบเทียบกรอบที่เลือกกับกรอบที่เหลือทั้งหมด. หากกรอบใดมีค่า IoU สูงกว่าค่า iou_threshold ที่กำหนดไว้ (หมายความว่าทับซ้อนกันมากเกินไป) ก็จะถูกกำจัดออกจากรายการ.
#  - ทำซ้ำ
#
# ทำขั้นตอนที่ 2 และ 3 ซ้ำไปเรื่อย ๆ จนกว่าจะไม่มีกรอบเหลืออยู่ในรายการ

# %% [markdown]
# ฟังก์ชัน apply_nms_to_all_templates
#
#     ฟังก์ชันนี้ทำหน้าที่รวบรวมผลลัพธ์การตรวจจับทั้งหมดจาก Template ทุกตัวเข้าด้วยกันก่อนที่จะนำไปใช้เทคนิค NMS
#
# - การรวบรวม
#  โค้ดจะวนลูปผ่าน Template แต่ละตัว เรียกใช้ match_template_masked เพื่อหาตำแหน่งที่ตรงกัน และเก็บข้อมูลของแต่ละการตรวจจับไว้ในรายการ all_detections ซึ่งประกอบด้วยตำแหน่ง, ค่าความเชื่อมั่น, หมายเลข Template และสีที่ใช้สำหรับวาดกรอบ
# - การประยุกต์ใช้ NMS
#  จากนั้นจะเรียกใช้ฟังก์ชัน non_maximum_suppression เพื่อกรองกรอบที่ทับซ้อนกันออกจากรายการ all_detections

# %%
def calculate_iou(box1, box2):
    # คำนวณ Intersection over Union (IoU) ระหว่าง 2 กรอบ
    # box format: ((x1, y1), (x2, y2))
    x1_1, y1_1 = box1[0]
    x2_1, y2_1 = box1[1]
    x1_2, y1_2 = box2[0]
    x2_2, y2_2 = box2[1]
    
    # หาพื้นที่ทับซ้อน (intersection)
    x1_i = max(x1_1, x1_2)
    y1_i = max(y1_1, y1_2)
    x2_i = min(x2_1, x2_2)
    y2_i = min(y2_1, y2_2)
    
    if x2_i <= x1_i or y2_i <= y1_i:
        return 0.0
    
    intersection_area = (x2_i - x1_i) * (y2_i - y1_i)
    
    # หาพื้นที่รวม (union)
    area1 = (x2_1 - x1_1) * (y2_1 - y1_1)
    area2 = (x2_2 - x1_2) * (y2_2 - y1_2)
    union_area = area1 + area2 - intersection_area
    
    return intersection_area / union_area if union_area > 0 else 0.0

def non_maximum_suppression(boxes_with_scores, iou_threshold=0.5):
    # Non-Maximum Suppression เพื่อกำจัดกรอบที่ทับซ้อน
    if len(boxes_with_scores) == 0:
        return []
    
    # เรียงตาม confidence score (จากมากไปน้อย)
    boxes_with_scores.sort(key=lambda x: x[2], reverse=True)
    
    selected_boxes = []
    
    while len(boxes_with_scores) > 0:
        # เลือกกรอบที่มี confidence สูงสุด
        current_box = boxes_with_scores.pop(0)
        selected_boxes.append(current_box)
        
        # กำจัดกรอบที่มี IoU สูงเกินไปกับกรอบที่เลือก
        boxes_with_scores = [
            box for box in boxes_with_scores
            if calculate_iou(current_box[:2], box[:2]) < iou_threshold
        ]
    
    return selected_boxes

def apply_nms_to_all_templates(iou_threshold=0.3):
    # ใช้ NMS กับผลลัพธ์จากทุก template
    all_detections = []
    colors = [(0, 255, 0), (255, 165, 0), (0, 0, 255)]
    
    # รวบรวมการตรวจจับทั้งหมด
    for i, tmpl_masked in enumerate(templates_masked):
        boxes, result = match_template_masked(main_masked, tmpl_masked, threshold)
        
        for box in boxes:
            top_left, bottom_right = box
            # คำนวณ confidence score
            confidence = result[top_left[1], top_left[0]] if top_left[1] < result.shape[0] and top_left[0] < result.shape[1] else 0
            
            # เก็บข้อมูล: (top_left, bottom_right, confidence, template_id, color)
            all_detections.append((top_left, bottom_right, confidence, i+1, colors[i % len(colors)]))
    
    # ใช้ NMS กับการตรวจจับทั้งหมด
    nms_detections = non_maximum_suppression(all_detections, iou_threshold)
    
    return nms_detections

# %% [markdown]
# # 10. สร้างภาพผลลัพธ์ที่ผ่าน NMS

# %% [markdown]
# ฟังก์ชัน create_final_result_images
# จะสร้างภาพสองภาพขึ้นมาเพื่อเปรียบเทียบกัน
# - ภาพก่อน NMS (img_before)
# โค้ดจะวนลูปเพื่อทำ Template Matching สำหรับ Template ทุกตัว และวาดกรอบสี่เหลี่ยมทั้งหมดที่ตรวจจับได้ลงบนภาพต้นฉบับ แม้ว่าหลายกรอบอาจจะทับซ้อนกันอยู่ก็ตาม
# - ภาพหลัง NMS (img_after)
# โค้ดจะเรียกใช้ฟังก์ชัน apply_nms_to_all_templates ที่ได้อธิบายไว้ก่อนหน้า เพื่อกรองเอากรอบที่ดีที่สุดและไม่ทับซ้อนกันออกมา จากนั้นจึงวาดเฉพาะกรอบเหล่านั้นลงบนภาพอีกภาพหนึ่ง

# %%
def create_final_result_images(iou_threshold=0.3):
    # สร้างภาพเปรียบเทียบก่อนและหลัง NMS
    
    # ภาพก่อน NMS (ทับซ้อนกัน)
    img_before = image_rgb.copy()
    colors = [(0, 255, 0), (255, 165, 0), (0, 0, 255)]
    total_boxes_before = 0
    
    for i, tmpl_masked in enumerate(templates_masked):
        boxes, result = match_template_masked(main_masked, tmpl_masked, threshold)
        total_boxes_before += len(boxes)
        
        for top_left, bottom_right in boxes:
            color = colors[i % len(colors)]
            cv2.rectangle(img_before, top_left, bottom_right, color, 2)
            # เพิ่มหมายเลข template
            cv2.putText(img_before, f"T{i+1}", 
                       (top_left[0]+5, top_left[1]+20), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)
    
    # ภาพหลัง NMS (ไม่ทับซ้อน)
    img_after = image_rgb.copy()
    nms_detections = apply_nms_to_all_templates(iou_threshold)
    
    for detection in nms_detections:
        top_left, bottom_right, confidence, template_id, color = detection
        
        # วาดกรอบ
        cv2.rectangle(img_after, top_left, bottom_right, color, 3)
        
        # วาดข้อความ template ID
        cv2.putText(img_after, f"T{template_id}", 
                   (top_left[0]+5, top_left[1]+20), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)
        
        # วาด confidence score
        cv2.putText(img_after, f"{confidence:.2f}", 
                   (top_left[0]+5, top_left[1]+40), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
    
    return img_before, img_after, total_boxes_before, len(nms_detections)

# สร้างภาพเปรียบเทียบ
img_before_nms, img_after_nms, count_before, count_after = create_final_result_images(iou_threshold=0.3)

# แสดงผลเปรียบเทียบ
plt.figure(figsize=(20, 10))

plt.subplot(1, 2, 1)
plt.imshow(img_before_nms)
plt.title(f"Before NMS\nTotal Detections: {count_before}")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img_after_nms)
plt.title(f"After NMS (IoU threshold: 0.3)\nFinal Detections: {count_after}")
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 11. แสดงรายละเอียดการทำ NMS

# %% [markdown]
# ฟังก์ชัน show_nms_details
# ทำหน้าที่แสดงข้อมูลสรุปเกี่ยวกับการทำงานของ NMS ในรูปแบบข้อความ
# - สรุปจำนวน
# โค้ดจะพิมพ์จำนวนการตรวจจับทั้งหมดที่พบก่อน NMS และจำนวนการตรวจจับสุดท้ายที่เหลืออยู่หลัง NMS เพื่อให้เห็นว่ามีกรอบที่ถูกกำจัดออกไปกี่กรอบ
#
# - ข้อมูลสุดท้าย
# จากนั้นโค้ดจะวนลูปแสดงรายละเอียดของแต่ละกรอบที่เหลืออยู่หลังการใช้ NMS ซึ่งรวมถึงพิกัด, ขนาด, และค่าความเชื่อมั่น ทำให้เราทราบได้อย่างแม่นยำว่ากรอบสุดท้ายที่โปรแกรมตัดสินใจเลือกคือกรอบไหนบ้าง

# %%
def show_nms_details():
    # แสดงรายละเอียดของ NMS process
    print("=== Non-Maximum Suppression Details ===")
    
    nms_detections = apply_nms_to_all_templates(iou_threshold=0.3)
    
    print(f"IoU Threshold: 0.3")
    print(f"Detections before NMS: {count_before}")
    print(f"Detections after NMS: {count_after}")
    print(f"Removed overlapping boxes: {count_before - count_after}")
    
    print(f"\n=== Final Detection Results ===")
    for i, detection in enumerate(nms_detections):
        top_left, bottom_right, confidence, template_id, color = detection
        x, y = top_left
        w = bottom_right[0] - top_left[0]
        h = bottom_right[1] - top_left[1]
        
        print(f"Detection {i+1}: Template T{template_id}")
        print(f"  Position: x={x}, y={y}, w={w}, h={h}")
        print(f"  Confidence: {confidence:.3f}")
        print(f"  Color: {color}")

show_nms_details()
# Out:
# === Non-Maximum Suppression Details ===
# IoU Threshold: 0.3
# Detections before NMS: 972
# Detections after NMS: 1
# Removed overlapping boxes: 971
#
# === Final Detection Results ===
# Detection 1: Template T2
#   Position: x=297, y=132, w=57, h=138
#   Confidence: 0.740
#   Color: (255, 165, 0)

# %% [markdown]
# # 12. ทดสอบ IoU Threshold ที่แตกต่างกัน

# %% [markdown]
# เป็นการทดลองเพื่อแสดงให้เห็นว่าการตั้งค่า IoU Threshold ที่แตกต่างกันส่งผลต่อผลลัพธ์ NMS อย่างไร
#
# - การทดสอบ
#  โค้ดจะวนลูปโดยใช้ค่า IoU Threshold ที่ต่างกัน (0.1, 0.3, 0.5, 0.7) และสร้างภาพผลลัพธ์หลัง NMS สำหรับแต่ละค่า
#
# - การแสดงผล
#  ภาพที่ได้จะถูกแสดงในรูปแบบตาราง 2x2 ทำให้เราสามารถเปรียบเทียบผลลัพธ์ได้อย่างง่ายดาย
#
# - ผลกระทบ
#     - IoU Threshold ต่ำ (เช่น 0.1): จะทำการกำจัดกรอบที่ทับซ้อนกันเพียงเล็กน้อยเท่านั้น ทำให้ยังอาจมีกรอบที่ทับซ้อนกันเหลืออยู่
#     - IoU Threshold สูง (เช่น 0.7): จะทำการกำจัดกรอบที่ทับซ้อนกันอย่างหนัก ทำให้เหลือกรอบที่ดีที่สุดเพียงกรอบเดียวเท่านั้น ซึ่งอาจทำให้สูญเสียการตรวจจับในกรณีที่มีวัตถุอยู่ใกล้กันแต่ไม่ทับซ้อนกันมากเกินไป

# %%
def compare_iou_thresholds():
    # เปรียบเทียบผลลัพธ์ที่ IoU threshold ต่างๆ
    thresholds = [0.1, 0.3, 0.5, 0.7]
    
    plt.figure(figsize=(20, 15))
    
    for i, iou_thresh in enumerate(thresholds):
        _, img_result, _, final_count = create_final_result_images(iou_thresh)
        
        plt.subplot(2, 2, i+1)
        plt.imshow(img_result)
        plt.title(f"IoU Threshold: {iou_thresh}\nDetections: {final_count}")
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()
    
    print("=== IoU Threshold Comparison ===")
    for iou_thresh in thresholds:
        nms_result = apply_nms_to_all_templates(iou_thresh)
        print(f"IoU {iou_thresh}: {len(nms_result)} detections")

compare_iou_thresholds()
# Out:
# === IoU Threshold Comparison ===
# IoU 0.1: 1 detections
# IoU 0.3: 1 detections
# IoU 0.5: 2 detections
# IoU 0.7: 9 detections
